# %% [markdown]
# # **EDA: ANÁLISIS EXPLORATORIO DE DATOS**
#
# Este notebook contiene la revisión exploratoria inicial de los datasets originales, con el objetivo de evaluar su estructura, calidad y estado general antes de aplicar cualquier proceso de limpieza o transformación.
#
# La revisión se realiza mediante una función estructurada que centraliza la validación del dataset y permite identificar posibles problemas de calidad de datos, inconsistencias y características relevantes para su posterior preparación.

# %%
# ============================================================================
# CONFIGURACIÓN DEL ENTORNO
# Importación de librerías para la manipulación, análisis y visualización
# de datos durante la fase exploratoria (EDA).
# ============================================================================

# Manipulación y análisis de datos
import pandas as pd
import numpy as np

# Visualización de datos
import seaborn as sns
import matplotlib.pyplot as plt


# ============================================================================
# CONFIGURACIÓN DE VISUALIZACIÓN EN PANDAS
# Ajuste de opciones para mejorar la legibilidad durante la inspección
# exploratoria, mostrando todas las columnas y un número acotado de filas.
# ============================================================================

pd.set_option("display.max_columns", None)  # mostrar todas las columnas
pd.set_option("display.max_rows", 100)      # limitar la visualización de filas
pd.set_option("display.width", None)        # ajustar automáticamente el ancho

# ============================================================================
# CARGA DE LOS DATASETS
# Se cargan los datasets originales desde data/raw manteniéndolos en su estado
# original (sin modificaciones) para el análisis inicial.
# ============================================================================
path1 = "../data/raw/data_science_job_posts_2025.csv"
path2 = "../data/raw/Distribución de las ofertas de empleo tech según el tipo de profesión tecnológica.csv"
path3 = "../data/raw/empresas por tamaño que contratan empleados ICT.csv"
path4 = "../data/raw/eu_data_jobs_salaries.csv"
path5 = "../data/raw/Número o proporción de ofertas de empleo online que buscan especialistas tecnológicos (ICT).csv"
path6 = "../data/raw/porcentaje de especialistas empleados por edad.csv"
path7 = "../data/raw/porcentaje de especialistas empleados por nivel educativo.csv"
path8 = "../data/raw/porcentaje de especialistas empleados por sector.csv"
path9 = "../data/raw/porcentaje de especialistas empleados por sexo.csv"
path10 = "../data/raw/porcentaje_profesionales_tecnologia_empleo_total_europa.csv"
path11 = "../data/raw/sectores que contratan empleados ICT.csv"
df1 = pd.read_csv(path1)
df2 = pd.read_csv(path2)
df3 = pd.read_csv(path3)
df4 = pd.read_csv(path4)
df5 = pd.read_csv(path5)
df6 = pd.read_csv(path6)
df7 = pd.read_csv(path7)
df8 = pd.read_csv(path8)
df9 = pd.read_csv(path9)
df10 = pd.read_csv(path10)
df11 = pd.read_csv(path11)

# %%
# ============================================================================
# VISUALIZACIÓN DE LOS DATASETS
# ============================================================================
display(df1.head())
display(df2.head())
display(df3.head())
display(df4.head())
display(df5.head())
display(df6.head())
display(df7.head())
display(df8.head())
display(df9.head())
display(df10.head())
display(df11.head())
# Out:
#         job_title seniority_level   status      company  \
# 0  data scientist          senior   hybrid  company_003
# 1  data scientist            lead   hybrid  company_005
# 2  data scientist          senior  on-site  company_007
# 3  data scientist          senior   hybrid  company_008
# 4  data scientist             NaN  on-site  company_009
#
#                                             location    post_date  \
# 0                             Grapevine, TX . Hybrid  17 days ago
# 1                            Fort Worth, TX . Hybrid  15 days ago
# 2  Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3  Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                            On-site   3 days ago
#
#             headquarter       industry ownership company_size  revenue  \
# 0   Bentonville, AR, US         Retail    Public     €352.44B   Public
# 1       Detroit, MI, US  Manufacturing    Public      155,030  €51.10B
# 2  Redwood City, CA, US     Technology    Public       25,930  €33.80B
# 3      San Jose, CA, US     Technology    Public       34,690  €81.71B
# 4      Stamford, CT, US        Finance   Private        1,800  Private
#
#                 salary                                             skills
# 0  €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1             €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2   €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3  €112,797 - €194,402                             ['sql', 'r', 'python']
# 4  €114,172 - €228,337                                                 []
#   STRUCTURE             STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
# 1  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
# 2  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
# 3  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
# 4  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
# 1  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
# 2  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
# 3  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
# 4  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
#
#   isco08 International Standard Classification of Occupations 2008 (ISCO-08)  \
# 0  OC133  Information and communications technology serv...
# 1  OC133  Information and communications technology serv...
# 2  OC133  Information and communications technology serv...
# 3  OC133  Information and communications technology serv...
# 4  OC133  Information and communications technology serv...
#
#   unit Unit of measure geo Geopolitical entity (reporting) TIME_PERIOD  Time  \
# 0   PC      Percentage  AT                         Austria     2019-Q4   NaN
# 1   PC      Percentage  AT                         Austria     2020-Q1   NaN
# 2   PC      Percentage  AT                         Austria     2020-Q2   NaN
# 3   PC      Percentage  AT                         Austria     2020-Q3   NaN
# 4   PC      Percentage  AT                         Austria     2020-Q4   NaN
#
#    OBS_VALUE  Observation value  OBS_FLAG  \
# 0        2.5                NaN       NaN
# 1        2.5                NaN       NaN
# 2        2.4                NaN       NaN
# 3        2.2                NaN       NaN
# 4        2.2                NaN       NaN
#
#    Observation status (Flag) V2 structure  CONF_STATUS  \
# 0                                     NaN          NaN
# 1                                     NaN          NaN
# 2                                     NaN          NaN
# 3                                     NaN          NaN
# 4                                     NaN          NaN
#
#    Confidentiality status (flag)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#   STRUCTURE               STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
# 1  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
# 2  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
# 3  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
# 4  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Enterprises that employ ICT specialists by siz...    A         Annual
# 1  Enterprises that employ ICT specialists by siz...    A         Annual
# 2  Enterprises that employ ICT specialists by siz...    A         Annual
# 3  Enterprises that employ ICT specialists by siz...    A         Annual
# 4  Enterprises that employ ICT specialists by siz...    A         Annual
#
#   size_emp Size classes in number of persons employed       nace_r2  \
# 0      0-9               From 0 to 9 persons employed  C10-S951_X_K
# 1      0-9               From 0 to 9 persons employed  C10-S951_X_K
# 2      0-9               From 0 to 9 persons employed  C10-S951_X_K
# 3      0-9               From 0 to 9 persons employed  C10-S951_X_K
# 4      0-9               From 0 to 9 persons employed  C10-S951_X_K
#
#   Statistical classification of economic activities in the European Community (NACE Rev. 2)  \
# 0  All activities (except agriculture, forestry a...
# 1  All activities (except agriculture, forestry a...
# 2  All activities (except agriculture, forestry a...
# 3  All activities (except agriculture, forestry a...
# 4  All activities (except agriculture, forestry a...
#
#   indic_is                      Information society indicator    unit  \
# 0  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 1  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 2  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 3  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 4  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
#
#              Unit of measure geo Geopolitical entity (reporting)  TIME_PERIOD  \
# 0  Percentage of enterprises  DE                         Germany         2022
# 1  Percentage of enterprises  DE                         Germany         2024
# 2  Percentage of enterprises  ES                           Spain         2017
# 3  Percentage of enterprises  ES                           Spain         2018
# 4  Percentage of enterprises  ES                           Spain         2019
#
#    Time  OBS_VALUE  Observation value OBS_FLAG  \
# 0   NaN       6.33                NaN      NaN
# 1   NaN       7.10                NaN      NaN
# 2   NaN       3.27                NaN      NaN
# 3   NaN       2.89                NaN      NaN
# 4   NaN       2.85                NaN      NaN
#
#   Observation status (Flag) V2 structure  CONF_STATUS  \
# 0                                    NaN          NaN
# 1                                    NaN          NaN
# 2                                    NaN          NaN
# 3                                    NaN          NaN
# 4                                    NaN          NaN
#
#    Confidentiality status (flag)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#    country currency                role  salary_min  salary_max
# 0  Austria      EUR        Data Analyst       35000       70000
# 1  Austria      EUR      Data Scientist       37000       85000
# 2  Austria      EUR    Business Analyst       35000       75000
# 3  Austria      EUR  IT Project Manager       40000       90000
# 4  Belgium      EUR        Data Analyst       35000       60000
#   STRUCTURE             STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
# 1  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
# 2  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
# 3  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
# 4  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency unit  \
# 0  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
# 1  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
# 2  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
# 3  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
# 4  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
#
#   Unit of measure geo Geopolitical entity (reporting) TIME_PERIOD  Time  \
# 0      Percentage  AT                         Austria     2019-Q4   NaN
# 1      Percentage  AT                         Austria     2020-Q1   NaN
# 2      Percentage  AT                         Austria     2020-Q2   NaN
# 3      Percentage  AT                         Austria     2020-Q3   NaN
# 4      Percentage  AT                         Austria     2020-Q4   NaN
#
#    OBS_VALUE  Observation value  OBS_FLAG  \
# 0       11.9                NaN       NaN
# 1       12.0                NaN       NaN
# 2       12.9                NaN       NaN
# 3       13.6                NaN       NaN
# 4       14.8                NaN       NaN
#
#    Observation status (Flag) V2 structure  CONF_STATUS  \
# 0                                     NaN          NaN
# 1                                     NaN          NaN
# 2                                     NaN          NaN
# 3                                     NaN          NaN
# 4                                     NaN          NaN
#
#    Confidentiality status (flag)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#   STRUCTURE               STRUCTURE_ID                   STRUCTURE_NAME freq  \
# 0  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
# 1  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
# 2  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
# 3  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
# 4  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
#
#   Time frequency unit Unit of measure     age            Age class geo  \
# 0         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
# 1         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
# 2         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
# 3         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
# 4         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
#
#   Geopolitical entity (reporting)  TIME_PERIOD  Time  OBS_VALUE  \
# 0                         Austria         2004   NaN       48.4
# 1                         Austria         2005   NaN       49.2
# 2                         Austria         2006   NaN       48.0
# 3                         Austria         2007   NaN       47.3
# 4                         Austria         2008   NaN       48.5
#
#    Observation value OBS_FLAG Observation status (Flag) V2 structure  \
# 0                NaN       be        break in time series, estimated
# 1                NaN       be        break in time series, estimated
# 2                NaN        e                              estimated
# 3                NaN       be        break in time series, estimated
# 4                NaN        e                              estimated
#
#    CONF_STATUS  Confidentiality status (flag)
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          NaN                            NaN
#   STRUCTURE               STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
# 1  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
# 2  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
# 3  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
# 4  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency unit  \
# 0  Employed ICT specialists by educational attain...    A         Annual   PC
# 1  Employed ICT specialists by educational attain...    A         Annual   PC
# 2  Employed ICT specialists by educational attain...    A         Annual   PC
# 3  Employed ICT specialists by educational attain...    A         Annual   PC
# 4  Employed ICT specialists by educational attain...    A         Annual   PC
#
#   Unit of measure isced11  \
# 0      Percentage   ED0-4
# 1      Percentage   ED0-4
# 2      Percentage   ED0-4
# 3      Percentage   ED0-4
# 4      Percentage   ED0-4
#
#   International Standard Classification of Education (ISCED 2011) geo  \
# 0  Less than primary, primary, secondary and post...               AT
# 1  Less than primary, primary, secondary and post...               AT
# 2  Less than primary, primary, secondary and post...               AT
# 3  Less than primary, primary, secondary and post...               AT
# 4  Less than primary, primary, secondary and post...               AT
#
#   Geopolitical entity (reporting)  TIME_PERIOD  Time  OBS_VALUE  \
# 0                         Austria         2004   NaN       63.2
# 1                         Austria         2005   NaN       66.0
# 2                         Austria         2006   NaN       64.9
# 3                         Austria         2007   NaN       63.4
# 4                         Austria         2008   NaN       67.1
#
#    Observation value OBS_FLAG Observation status (Flag) V2 structure  \
# 0                NaN       be        break in time series, estimated
# 1                NaN       be        break in time series, estimated
# 2                NaN       be        break in time series, estimated
# 3                NaN       be        break in time series, estimated
# 4                NaN        e                              estimated
#
#    CONF_STATUS  Confidentiality status (flag)
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          NaN                            NaN
#   STRUCTURE                STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
# 1  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
# 2  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
# 3  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
# 4  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
#
#                                      STRUCTURE_NAME freq Time frequency  \
# 0  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
# 1  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
# 2  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
# 3  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
# 4  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
#
#   nace_r2  \
# 0       A
# 1       A
# 2       A
# 3       A
# 4       A
#
#   Statistical classification of economic activities in the European Community (NACE Rev. 2)  \
# 0                  Agriculture, forestry and fishing
# 1                  Agriculture, forestry and fishing
# 2                  Agriculture, forestry and fishing
# 3                  Agriculture, forestry and fishing
# 4                  Agriculture, forestry and fishing
#
#      unit                 Unit of measure geo Geopolitical entity (reporting)  \
# 0  PC_EMP  Percentage of total employment  AT                         Austria
# 1  PC_EMP  Percentage of total employment  AT                         Austria
# 2  PC_EMP  Percentage of total employment  AT                         Austria
# 3  PC_EMP  Percentage of total employment  AT                         Austria
# 4  PC_EMP  Percentage of total employment  AT                         Austria
#
#    TIME_PERIOD  Time  OBS_VALUE  Observation value OBS_FLAG  \
# 0         2008   NaN        NaN                NaN       bu
# 1         2010   NaN        NaN                NaN        u
# 2         2011   NaN        NaN                NaN       bu
# 3         2012   NaN        NaN                NaN        u
# 4         2013   NaN        NaN                NaN        u
#
#   Observation status (Flag) V2 structure  CONF_STATUS  \
# 0  break in time series, low reliability          NaN
# 1                        low reliability          NaN
# 2  break in time series, low reliability          NaN
# 3                        low reliability          NaN
# 4                        low reliability          NaN
#
#    Confidentiality status (flag)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#   STRUCTURE               STRUCTURE_ID                   STRUCTURE_NAME freq  \
# 0  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
# 1  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
# 2  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
# 3  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
# 4  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
#
#   Time frequency unit Unit of measure sex      Sex geo  \
# 0         Annual   PC      Percentage   F  Females  AT
# 1         Annual   PC      Percentage   F  Females  AT
# 2         Annual   PC      Percentage   F  Females  AT
# 3         Annual   PC      Percentage   F  Females  AT
# 4         Annual   PC      Percentage   F  Females  AT
#
#   Geopolitical entity (reporting)  TIME_PERIOD  Time  OBS_VALUE  \
# 0                         Austria         2004   NaN       22.1
# 1                         Austria         2005   NaN       20.0
# 2                         Austria         2006   NaN       19.7
# 3                         Austria         2007   NaN       20.9
# 4                         Austria         2008   NaN       17.6
#
#    Observation value OBS_FLAG Observation status (Flag) V2 structure  \
# 0                NaN       be        break in time series, estimated
# 1                NaN       be        break in time series, estimated
# 2                NaN        e                              estimated
# 3                NaN       be        break in time series, estimated
# 4                NaN        e                              estimated
#
#    CONF_STATUS  Confidentiality status (flag)
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          NaN                            NaN
#                     DATAFLOW        LAST UPDATE    freq  \
# 0  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
# 1  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
# 2  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
# 3  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
# 4  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
#
#                              unit      geo  TIME_PERIOD  OBS_VALUE OBS_FLAG  \
# 0  Percentage of total employment  Austria         2004        2.9       be
# 1  Percentage of total employment  Austria         2005        3.1       be
# 2  Percentage of total employment  Austria         2006        3.3        e
# 3  Percentage of total employment  Austria         2007        3.3       be
# 4  Percentage of total employment  Austria         2008        3.3        e
#
#    CONF_STATUS
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#   STRUCTURE                 STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
# 1  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
# 2  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
# 3  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
# 4  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Enterprises that employ ICT specialists by NAC...    A         Annual
# 1  Enterprises that employ ICT specialists by NAC...    A         Annual
# 2  Enterprises that employ ICT specialists by NAC...    A         Annual
# 3  Enterprises that employ ICT specialists by NAC...    A         Annual
# 4  Enterprises that employ ICT specialists by NAC...    A         Annual
#
#   size_emp Size classes in number of persons employed nace_r2  \
# 0     GE10                10 persons employed or more       C
# 1     GE10                10 persons employed or more       C
# 2     GE10                10 persons employed or more       C
# 3     GE10                10 persons employed or more       C
# 4     GE10                10 persons employed or more       C
#
#   Statistical classification of economic activities in the European Community (NACE Rev. 2)  \
# 0                                      Manufacturing
# 1                                      Manufacturing
# 2                                      Manufacturing
# 3                                      Manufacturing
# 4                                      Manufacturing
#
#   indic_is                      Information society indicator    unit  \
# 0  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 1  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 2  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 3  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 4  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
#
#              Unit of measure geo Geopolitical entity (reporting)  TIME_PERIOD  \
# 0  Percentage of enterprises  AL                         Albania         2022
# 1  Percentage of enterprises  AT                         Austria         2012
# 2  Percentage of enterprises  AT                         Austria         2014
# 3  Percentage of enterprises  AT                         Austria         2015
# 4  Percentage of enterprises  AT                         Austria         2016
#
#    Time  OBS_VALUE  Observation value OBS_FLAG  \
# 0   NaN      11.22                NaN        b
# 1   NaN      35.12                NaN      NaN
# 2   NaN      31.01                NaN      NaN
# 3   NaN      31.44                NaN      NaN
# 4   NaN      35.22                NaN      NaN
#
#   Observation status (Flag) V2 structure CONF_STATUS  \
# 0                   break in time series         NaN
# 1                                    NaN         NaN
# 2                                    NaN         NaN
# 3                                    NaN         NaN
# 4                                    NaN         NaN
#
#   Confidentiality status (flag)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN

# %%
def eda(df):
    """
    Realiza un análisis exploratorio estructurado (EDA) sobre un DataFrame.

    Parámetros
    ----------
    df : pandas.DataFrame
        Dataset a analizar.

    Devuelve
    --------
    None
        La función no devuelve ningún objeto. Muestra en pantalla el análisis
        exploratorio, estadísticas descriptivas, visualizaciones y flags de calidad.

    Qué analiza
    -----------
    1) Visión general:
       - Vista inicial (head), dimensiones, info() y duplicados.

    2) Calidad de columnas:
       - Tabla resumen por columna (tipos, nulos, cardinalidad).
       - Flags por umbral de nulos (bajo/moderado/alto).

    3) Análisis de nulos:
       - Categóricas: distribución (porcentaje + recuento) incluyendo NaN.
       - Numéricas: % nulos + histograma + KDE (si aplica) + media/mediana/moda.

    4) Estadística descriptiva y controles básicos:
       - Describe numéricas y categóricas.
       - Flags: valores negativos en numéricas; varianza 0 en numéricas.

    5) Outliers:
       - Detección por IQR (1.5x) + boxplot para columnas con outliers.

    Objetivo
    --------
    Facilitar decisiones de limpieza (imputación, tipado, tratamiento de outliers)
    y comprensión del dataset antes de aplicar transformaciones.
    """

    # ==================================================
    # 1) VISIÓN GENERAL
    # ==================================================
    # Objetivo: obtener una primera fotografía del dataset (tamaño, estructura,
    # tipos básicos y presencia de duplicados) antes de entrar en métricas y flags.
    print("📐 VISIÓN GENERAL DEL DATASET")
    print("Vista inicial (primeras 5 filas):")
    display(df.head())

    filas, columnas = df.shape
    print(f"Dimensiones: {filas} filas × {columnas} columnas")

    print("\nInformación general (dtypes, nulos, memoria):")
    df.info()

    duplicados = df.duplicated().sum()
    pct_dup = (duplicados / filas * 100) if filas else 0
    print(f"\n🚩 FLAG: duplicados - Filas duplicadas: {duplicados} ({pct_dup:.2f}%)")
    print("-" * 70)

    # ==================================================
    # 2) CALIDAD DE COLUMNAS
    # ==================================================
    # Objetivo: construir una tabla resumen por columna para identificar
    # rápidamente variables problemáticas (nulos, tipos).
    print("🚑 CALIDAD DE COLUMNAS")

    calidad = (
        pd.DataFrame({
            "Tipo": df.dtypes,
            "Nulos": df.isnull().sum(),
            "% Nulos": (df.isnull().mean() * 100).round(2),
            "Valores Únicos": df.nunique(),
            "% Cardinalidad": (df.nunique()/filas*100).round(2)
            })
        .sort_values("% Nulos", ascending=False)
    )

    display(calidad)

    # ---- Flags por nulos (umbrales) ----
    # Objetivo: priorizar el tratamiento de nulos clasificando columnas según severidad.
    cols_nulos_bajo = calidad[(calidad["% Nulos"] > 0) & (calidad["% Nulos"] <= 5)].index.tolist()
    cols_nulos_moderado = calidad[(calidad["% Nulos"] > 5) & (calidad["% Nulos"] <= 20)].index.tolist()
    cols_nulos_alto = calidad[calidad["% Nulos"] > 20].index.tolist()

    print("\n🚩 FLAG: nulos - Clasificación por umbral (% nulos)")
    print("  🟢 Bajo (≤ 5%):")
    if cols_nulos_bajo:
        for col in cols_nulos_bajo:
            print(f"    - {col} ({calidad.loc[col, '% Nulos']:.2f}%)")
    else:
        print("    - Ninguna")

    print("  🟡 Moderado (5%–20%):")
    if cols_nulos_moderado:
        for col in cols_nulos_moderado:
            print(f"    - {col} ({calidad.loc[col, '% Nulos']:.2f}%)")
    else:
        print("    - Ninguna")

    print("  🔴 Alto (> 20%):")
    if cols_nulos_alto:
        for col in cols_nulos_alto:
            print(f"    - {col} ({calidad.loc[col, '% Nulos']:.2f}%)")
    else:
        print("    - Ninguna")

    # ==================================================
    # 3) ANÁLISIS DE NULOS
    # ==================================================
    # Objetivo: identificar variables con nulos y entender el patrón básico:
    # - En categóricas: distribución de categorías + NaN.
    # - En numéricas: impacto de nulos y forma de la distribución para orientar imputación.

    # --- 3.1 Nulos en categóricas ---
    cols_cat = df.select_dtypes(include=["O"]).columns
    cols_cat_nulos = [c for c in cols_cat if df[c].isnull().any()]

    print("\n🔤 NULOS EN VARIABLES CATEGÓRICAS")
    if cols_cat_nulos:
        for col in cols_cat_nulos:
            pct_nulos = df[col].isnull().mean() * 100
            print(f"\n📌 {col} — 🚩 FLAG: nulos_categorica ({pct_nulos:.2f}%)")

            dist_pct = df[col].value_counts(normalize=True, dropna=False) * 100
            dist_cnt = df[col].value_counts(dropna=False)

            display(pd.DataFrame({
                "Porcentaje": dist_pct.round(2),
                "Recuento": dist_cnt
            }))
    else:
        print("No hay variables categóricas con nulos.")



    # --- 3.2 Nulos en numéricas ---
    num_cols = df.select_dtypes(include=["number"]).columns
    cols_num_nulos = [c for c in num_cols if df[c].isnull().any()]

    print("\n📊 NULOS EN VARIABLES NUMÉRICAS")
    if cols_num_nulos:
        for col in cols_num_nulos:
            pct_nulos = df[col].isnull().mean() * 100
            print(f"\n📌 {col} — 🚩 FLAG: nulos_numerica ({pct_nulos:.2f}%)")

            plt.figure(figsize=(6, 4))
            s = pd.to_numeric(df[col], errors="coerce").dropna()

            # Histograma en densidad para comparar con KDE si aplica
            s.hist(bins=30, density=True, alpha=0.6)

            # KDE solo si hay suficientes datos y variabilidad
            if (len(s) >= 20) and (s.nunique() > 1) and (s.std() > 0):
                try:
                    s.plot(kind="kde", linewidth=2)
                except Exception:
                    pass

            plt.title(f"Distribución de {col}")
            plt.xlabel(col)
            plt.ylabel("Densidad")
            plt.legend()
            plt.show()
    else:
        print("No hay variables numéricas con nulos.")

    # ==================================================
    # 4) ESTADÍSTICAS DESCRIPTIVAS + FLAGS BÁSICAS
    # ==================================================
    # Objetivo: describir numéricas/categóricas y detectar incoherencias claras
    # (negativos y varianza 0) que suelen indicar errores o variables sin valor.
    print("\n📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS")
    if len(num_cols) > 0:
        display(df[num_cols].describe().T)

        cols_negativos = df[num_cols].columns[df[num_cols].min() < 0].tolist()
        cols_var_0 = df[num_cols].columns[df[num_cols].var() == 0].tolist()

        if cols_negativos:
            print("\n🚩 FLAG: rango - Valores negativos detectados en variables numéricas")
            for col in cols_negativos:
                min_val = df[col].min()
                print(f"  - {col} (mínimo: {min_val})")
        else:
            print("\n✅ No se detectaron valores negativos en variables numéricas.")

        if cols_var_0:
            print("\n🚩 FLAG: varianza - Variables con varianza 0 (sin variabilidad)")
            for col in cols_var_0:
                print(f"  - {col}")
        else:
            print("\n✅ No se detectaron variables con varianza 0.")
    else:
        print("No hay variables numéricas para describir.")

    print("\n🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS")
    if len(cols_cat) > 0:
        display(df[cols_cat].describe().T)
    else:
        print("No hay variables categóricas para describir.")

    # ==================================================
    # 4.1) MUESTRA DE CATEGORÍAS ÚNICAS (TOP N)
    # ==================================================
    # Objetivo: validar formato y consistencia de variables categóricas mostrando
    # una muestra acotada.
    print("\n📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS")
    if len(cols_cat) > 0:
        for col in cols_cat:
            n_unique = df[col].nunique(dropna=False)
            print(f"\n📌 {col} — {n_unique} valores únicos (mostrando hasta 10)")
            valores = pd.Series(df[col].dropna().unique()).head(10)
            display(pd.DataFrame(valores, columns=["Valor (muestra)"]))
    else:
        print("No hay variables categóricas.")

    # ==================================================
    # 5) OUTLIERS (IQR)
    # ==================================================
    # Objetivo: detectar valores atípicos con IQR (1.5x) como señal para posibles
    # transformaciones, winsorización o tratamiento específico en limpieza.
    print("\n⚠️ OUTLIERS — Método IQR (1.5x)")
    if len(num_cols) > 0:
        for col in num_cols:
            s = pd.to_numeric(df[col], errors="coerce").dropna()
            if s.empty:
                continue

            q1 = s.quantile(0.25)
            q3 = s.quantile(0.75)
            iqr = q3 - q1
            if iqr == 0:
                continue

            limite_inferior = q1 - 1.5 * iqr
            limite_superior = q3 + 1.5 * iqr
            outliers = ((s < limite_inferior) | (s > limite_superior)).sum()

            if outliers > 0:
                pct_out = outliers / len(s) * 100
                print(f"🚩 FLAG: outliers - {col}: {outliers} ({pct_out:.2f}%)")

                plt.figure(figsize=(6, 2))
                sns.boxplot(x=s)
                plt.title(f"Boxplot de {col}")
                plt.show()
    else:
        print("No hay variables numéricas para análisis de outliers.")

    print("\n🏁 REVISIÓN EDA FINALIZADA")

# %%
eda(df1)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#         job_title seniority_level   status      company  \
# 0  data scientist          senior   hybrid  company_003
# 1  data scientist            lead   hybrid  company_005
# 2  data scientist          senior  on-site  company_007
# 3  data scientist          senior   hybrid  company_008
# 4  data scientist             NaN  on-site  company_009
#
#                                             location    post_date  \
# 0                             Grapevine, TX . Hybrid  17 days ago
# 1                            Fort Worth, TX . Hybrid  15 days ago
# 2  Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3  Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                            On-site   3 days ago
#
#             headquarter       industry ownership company_size  revenue  \
# 0   Bentonville, AR, US         Retail    Public     €352.44B   Public
# 1       Detroit, MI, US  Manufacturing    Public      155,030  €51.10B
# 2  Redwood City, CA, US     Technology    Public       25,930  €33.80B
# 3      San Jose, CA, US     Technology    Public       34,690  €81.71B
# 4      Stamford, CT, US        Finance   Private        1,800  Private
#
#                 salary                                             skills
# 0  €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1             €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2   €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3  €112,797 - €194,402                             ['sql', 'r', 'python']
# 4  €114,172 - €228,337                                                 []
# Dimensiones: 944 filas × 13 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        941 non-null    object
#  1   seniority_level  884 non-null    object
#  2   status           688 non-null    object
#  3   company          944 non-null    object
#  4   location         942 non-null    object
#  5   post_date        944 non-null    object
#  6   headquarter      944 non-null    object
#  7   industry         944 non-null    object
#  8   ownership        897 non-null    object
#  9   company_size     944 non-null    object
#  10  revenue          929 non-null    object
#  11  salary           944 non-null    object
#  12  skills           944 non-null    object
# dtypes: object(13)
# memory usage: 96.0+ KB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                    Tipo  Nulos  % Nulos  Valores Únicos  % Cardinalidad
# status           object    256    27.12               3            0.32
# seniority_level  object     60     6.36               4            0.42
# ownership        object     47     4.98               2            0.21
# revenue          object     15     1.59             312           33.05
# job_title        object      3     0.32               4            0.42
# location         object      2     0.21             431           45.66
# company          object      0     0.00             420           44.49
# headquarter      object      0     0.00             197           20.87
# post_date        object      0     0.00              42            4.45
# industry         object      0     0.00               8            0.85
# company_size     object      0     0.00             510           54.03
# salary           object      0     0.00             896           94.92
# skills           object      0     0.00             400           42.37
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - ownership (4.98%)
#     - revenue (1.59%)
#     - job_title (0.32%)
#     - location (0.21%)
#   🟡 Moderado (5%–20%):
#     - seniority_level (6.36%)
#   🔴 Alto (> 20%):
#     - status (27.12%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
#
# 📌 job_title — 🚩 FLAG: nulos_categorica (0.32%)
#                            Porcentaje  Recuento
# job_title
# data scientist                  90.68       856
# machine learning engineer        8.47        80
# data engineer                    0.42         4
# NaN                              0.32         3
# data analyst                     0.11         1
# 📌 seniority_level — 🚩 FLAG: nulos_categorica (6.36%)
#                  Porcentaje  Recuento
# seniority_level
# senior                66.74       630
# lead                  12.29       116
# midlevel              11.97       113
# NaN                    6.36        60
# junior                 2.65        25
# 📌 status — 🚩 FLAG: nulos_categorica (27.12%)
#          Porcentaje  Recuento
# status
# on-site       38.45       363
# NaN           27.12       256
# hybrid        21.93       207
# remote        12.50       118
# 📌 location — 🚩 FLAG: nulos_categorica (0.21%)
#                                                     Porcentaje  Recuento
# location
# Bengaluru, Karnataka, India                               5.51        52
# Fully Remote                                              3.71        35
# New York, NY                                              2.33        22
# United States                                             2.33        22
# On-site                                                   1.91        18
# ...                                                        ...       ...
# Minneapolis, MN . Fully Remote                            0.11         1
# Titusville, NJ . Titusville, New Jersey, United...        0.11         1
# Berlin, Berlin, Germany                                   0.11         1
# Boston, MA . Newark, DE . Tampa, FL . Kennesaw,...        0.11         1
# Zurich, Zurich, Switzerland                               0.11         1
#
# [432 rows x 2 columns]
# 📌 ownership — 🚩 FLAG: nulos_categorica (4.98%)
#            Porcentaje  Recuento
# ownership
# Public          61.33       579
# Private         33.69       318
# NaN              4.98        47
# 📌 revenue — 🚩 FLAG: nulos_categorica (1.59%)
#            Porcentaje  Recuento
# revenue
# Private         26.17       247
# Public          24.05       227
# Education        2.12        20
# NaN              1.59        15
# Nonprofit        1.27        12
# ...               ...       ...
# €53.20B          0.11         1
# €29.92B          0.11         1
# €30.07B          0.11         1
# €1.72B           0.11         1
# €43.18B          0.11         1
#
# [313 rows x 2 columns]
# 📊 NULOS EN VARIABLES NUMÉRICAS
# No hay variables numéricas con nulos.
#
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
# No hay variables numéricas para describir.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#                 count unique                          top freq
# job_title         941      4               data scientist  856
# seniority_level   884      4                       senior  630
# status            688      3                      on-site  363
# company           944    420                  company_134   30
# location          942    431  Bengaluru, Karnataka, India   52
# post_date         944     42                  a month ago  167
# headquarter       944    197        San Francisco, CA, US   91
# industry          944      8                   Technology  582
# ownership         897      2                       Public  579
# company_size      944    510                          900   18
# revenue           929    312                      Private  247
# salary            944    896                      €25,214    3
# skills            944    400                           []  201
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 job_title — 5 valores únicos (mostrando hasta 10)
#              Valor (muestra)
# 0             data scientist
# 1  machine learning engineer
# 2               data analyst
# 3              data engineer
# 📌 seniority_level — 5 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          senior
# 1            lead
# 2          junior
# 3        midlevel
# 📌 status — 4 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          hybrid
# 1         on-site
# 2          remote
# 📌 company — 420 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0     company_003
# 1     company_005
# 2     company_007
# 3     company_008
# 4     company_009
# 5     company_013
# 6     company_014
# 7     company_015
# 8     company_019
# 9     company_021
# 📌 location — 432 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0                             Grapevine, TX . Hybrid
# 1                            Fort Worth, TX . Hybrid
# 2  Austin, TX . Toronto, Ontario, Canada . Kirkla...
# 3  Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...
# 4                                            On-site
# 5                                       New York, NY
# 6                                       Berkeley, CA
# 7                                     Menlo Park, CA
# 8                                       Fully Remote
# 9                                        Atlanta, GA
# 📌 post_date — 42 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0     17 days ago
# 1     15 days ago
# 2     a month ago
# 3      8 days ago
# 4      3 days ago
# 5    3 months ago
# 6      9 days ago
# 7      6 days ago
# 8       a day ago
# 9     19 days ago
# 📌 headquarter — 197 valores únicos (mostrando hasta 10)
#          Valor (muestra)
# 0    Bentonville, AR, US
# 1        Detroit, MI, US
# 2   Redwood City, CA, US
# 3       San Jose, CA, US
# 4       Stamford, CT, US
# 5       New York, NY, US
# 6       Berkeley, CA, US
# 7     Menlo Park, CA, US
# 8         Boston, MA, US
# 9  San Francisco, CA, US
# 📌 industry — 8 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Retail
# 1   Manufacturing
# 2      Technology
# 3         Finance
# 4       Education
# 5      Healthcare
# 6          Energy
# 7       Logistics
# 📌 ownership — 3 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Public
# 1         Private
# 📌 company_size — 510 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0        €352.44B
# 1         155,030
# 2          25,930
# 3          34,690
# 4           1,800
# 5             150
# 6          17,471
# 7             900
# 8             126
# 9           5,520
# 📌 revenue — 313 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Public
# 1         €51.10B
# 2         €33.80B
# 3         €81.71B
# 4         Private
# 5          €2.16B
# 6       Education
# 7         €61.06B
# 8        €128.13B
# 9         €43.18B
# 📌 salary — 896 valores únicos (mostrando hasta 10)
#        Valor (muestra)
# 0  €100,472 - €200,938
# 1             €118,733
# 2   €94,987 - €159,559
# 3  €112,797 - €194,402
# 4  €114,172 - €228,337
# 5  €196,371 - €251,170
# 6    €51,330 - €70,144
# 7  €121,480 - €132,440
# 8             €207,331
# 9             €219,201
# 📌 skills — 400 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3                             ['sql', 'r', 'python']
# 4                                                 []
# 5  ['scikit-learn', 'python', 'scala', 'sql', 'ma...
# 6                               ['machine learning']
# 7  ['pytorch', 'r', 'python', 'sql', 'machine lea...
# 8                          ['java', 'git', 'python']
# 9              ['sql', 'machine learning', 'python']
# ⚠️ OUTLIERS — Método IQR (1.5x)
# No hay variables numéricas para análisis de outliers.
#
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df2)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#   STRUCTURE             STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
# 1  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
# 2  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
# 3  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
# 4  dataflow  ESTAT:ISOC_SK_OJA2(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
# 1  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
# 2  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
# 3  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
# 4  Distribution by occupation (ISCO-08) of the la...    Q      Quarterly
#
#   isco08 International Standard Classification of Occupations 2008 (ISCO-08)  \
# 0  OC133  Information and communications technology serv...
# 1  OC133  Information and communications technology serv...
# 2  OC133  Information and communications technology serv...
# 3  OC133  Information and communications technology serv...
# 4  OC133  Information and communications technology serv...
#
#   unit Unit of measure geo Geopolitical entity (reporting) TIME_PERIOD  Time  \
# 0   PC      Percentage  AT                         Austria     2019-Q4   NaN
# 1   PC      Percentage  AT                         Austria     2020-Q1   NaN
# 2   PC      Percentage  AT                         Austria     2020-Q2   NaN
# 3   PC      Percentage  AT                         Austria     2020-Q3   NaN
# 4   PC      Percentage  AT                         Austria     2020-Q4   NaN
#
#    OBS_VALUE  Observation value  OBS_FLAG  \
# 0        2.5                NaN       NaN
# 1        2.5                NaN       NaN
# 2        2.4                NaN       NaN
# 3        2.2                NaN       NaN
# 4        2.2                NaN       NaN
#
#    Observation status (Flag) V2 structure  CONF_STATUS  \
# 0                                     NaN          NaN
# 1                                     NaN          NaN
# 2                                     NaN          NaN
# 3                                     NaN          NaN
# 4                                     NaN          NaN
#
#    Confidentiality status (flag)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# Dimensiones: 4533 filas × 19 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4533 entries, 0 to 4532
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   STRUCTURE                                                            4533 non-null   object
#  1   STRUCTURE_ID                                                         4533 non-null   object
#  2   STRUCTURE_NAME                                                       4533 non-null   object
#  3   freq                                                                 4533 non-null   object
#  4   Time frequency                                                       4533 non-null   object
#  5   isco08                                                               4533 non-null   object
#  6   International Standard Classification of Occupations 2008 (ISCO-08)  4533 non-null   object
#  7   unit                                                                 4533 non-null   object
#  8   Unit of measure                                                      4533 non-null   object
#  9   geo                                                                  4533 non-null   object
#  10  Geopolitical entity (reporting)                                      4533 non-null   object
#  11  TIME_PERIOD                                                          4533 non-null   object
#  12  Time                                                                 0 non-null      float64
#  13  OBS_VALUE                                                            4533 non-null   float64
#  14  Observation value                                                    0 non-null      float64
#  15  OBS_FLAG                                                             0 non-null      float64
#  16  Observation status (Flag) V2 structure                               0 non-null      float64
#  17  CONF_STATUS                                                          0 non-null      float64
#  18  Confidentiality status (flag)                                        0 non-null      float64
# dtypes: float64(7), object(12)
# memory usage: 673.0+ KB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                                                        Tipo  Nulos  % Nulos  \
# Confidentiality status (flag)                       float64   4533    100.0
# Observation status (Flag) V2 structure              float64   4533    100.0
# OBS_FLAG                                            float64   4533    100.0
# Observation value                                   float64   4533    100.0
# Time                                                float64   4533    100.0
# CONF_STATUS                                         float64   4533    100.0
# STRUCTURE                                            object      0      0.0
# STRUCTURE_NAME                                       object      0      0.0
# STRUCTURE_ID                                         object      0      0.0
# freq                                                 object      0      0.0
# Time frequency                                       object      0      0.0
# Geopolitical entity (reporting)                      object      0      0.0
# geo                                                  object      0      0.0
# Unit of measure                                      object      0      0.0
# unit                                                 object      0      0.0
# International Standard Classification of Occupa...   object      0      0.0
# isco08                                               object      0      0.0
# OBS_VALUE                                           float64      0      0.0
# TIME_PERIOD                                          object      0      0.0
#
#                                                     Valores Únicos  \
# Confidentiality status (flag)                                    0
# Observation status (Flag) V2 structure                           0
# OBS_FLAG                                                         0
# Observation value                                                0
# Time                                                             0
# CONF_STATUS                                                      0
# STRUCTURE                                                        1
# STRUCTURE_NAME                                                   1
# STRUCTURE_ID                                                     1
# freq                                                             1
# Time frequency                                                   1
# Geopolitical entity (reporting)                                 33
# geo                                                             33
# Unit of measure                                                  1
# unit                                                             1
# International Standard Classification of Occupa...               7
# isco08                                                           7
# OBS_VALUE                                                      584
# TIME_PERIOD                                                     23
#
#                                                     % Cardinalidad
# Confidentiality status (flag)                                 0.00
# Observation status (Flag) V2 structure                        0.00
# OBS_FLAG                                                      0.00
# Observation value                                             0.00
# Time                                                          0.00
# CONF_STATUS                                                   0.00
# STRUCTURE                                                     0.02
# STRUCTURE_NAME                                                0.02
# STRUCTURE_ID                                                  0.02
# freq                                                          0.02
# Time frequency                                                0.02
# Geopolitical entity (reporting)                               0.73
# geo                                                           0.73
# Unit of measure                                               0.02
# unit                                                          0.02
# International Standard Classification of Occupa...            0.15
# isco08                                                        0.15
# OBS_VALUE                                                    12.88
# TIME_PERIOD                                                   0.51
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - Ninguna
#   🟡 Moderado (5%–20%):
#     - Ninguna
#   🔴 Alto (> 20%):
#     - Confidentiality status (flag) (100.00%)
#     - Observation status (Flag) V2 structure (100.00%)
#     - OBS_FLAG (100.00%)
#     - Observation value (100.00%)
#     - Time (100.00%)
#     - CONF_STATUS (100.00%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
# No hay variables categóricas con nulos.
#
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 Time — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 Observation value — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 OBS_FLAG — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 Observation status (Flag) V2 structure — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 CONF_STATUS — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 Confidentiality status (flag) — 🚩 FLAG: nulos_numerica (100.00%)
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#                                          count       mean        std  min  \
# Time                                       0.0        NaN        NaN  NaN
# OBS_VALUE                               4533.0  14.835473  18.179049  0.1
# Observation value                          0.0        NaN        NaN  NaN
# OBS_FLAG                                   0.0        NaN        NaN  NaN
# Observation status (Flag) V2 structure     0.0        NaN        NaN  NaN
# CONF_STATUS                                0.0        NaN        NaN  NaN
# Confidentiality status (flag)              0.0        NaN        NaN  NaN
#
#                                         25%  50%   75%   max
# Time                                    NaN  NaN   NaN   NaN
# OBS_VALUE                               3.4  8.3  14.8  75.1
# Observation value                       NaN  NaN   NaN   NaN
# OBS_FLAG                                NaN  NaN   NaN   NaN
# Observation status (Flag) V2 structure  NaN  NaN   NaN   NaN
# CONF_STATUS                             NaN  NaN   NaN   NaN
# Confidentiality status (flag)           NaN  NaN   NaN   NaN
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#                                                    count unique  \
# STRUCTURE                                           4533      1
# STRUCTURE_ID                                        4533      1
# STRUCTURE_NAME                                      4533      1
# freq                                                4533      1
# Time frequency                                      4533      1
# isco08                                              4533      7
# International Standard Classification of Occupa...  4533      7
# unit                                                4533      1
# Unit of measure                                     4533      1
# geo                                                 4533     33
# Geopolitical entity (reporting)                     4533     33
# TIME_PERIOD                                         4533     23
#
#                                                                                                   top  \
# STRUCTURE                                                                                    dataflow
# STRUCTURE_ID                                                                  ESTAT:ISOC_SK_OJA2(1.0)
# STRUCTURE_NAME                                      Distribution by occupation (ISCO-08) of the la...
# freq                                                                                                Q
# Time frequency                                                                              Quarterly
# isco08                                                                                          OC251
# International Standard Classification of Occupa...  Software and applications developers and analysts
# unit                                                                                               PC
# Unit of measure                                                                            Percentage
# geo                                                                                                AT
# Geopolitical entity (reporting)                                                               Austria
# TIME_PERIOD                                                                                   2024-Q1
#
#                                                     freq
# STRUCTURE                                           4533
# STRUCTURE_ID                                        4533
# STRUCTURE_NAME                                      4533
# freq                                                4533
# Time frequency                                      4533
# isco08                                               675
# International Standard Classification of Occupa...   675
# unit                                                4533
# Unit of measure                                     4533
# geo                                                  161
# Geopolitical entity (reporting)                      161
# TIME_PERIOD                                          218
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 STRUCTURE — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0        dataflow
# 📌 STRUCTURE_ID — 1 valores únicos (mostrando hasta 10)
#            Valor (muestra)
# 0  ESTAT:ISOC_SK_OJA2(1.0)
# 📌 STRUCTURE_NAME — 1 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  Distribution by occupation (ISCO-08) of the la...
# 📌 freq — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               Q
# 📌 Time frequency — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0       Quarterly
# 📌 isco08 — 7 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0           OC133
# 1           OC251
# 2           OC252
# 3           OC351
# 4           OC352
# 5           OC742
# 6         OTH_ICT
# 📌 International Standard Classification of Occupations 2008 (ISCO-08) — 7 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  Information and communications technology serv...
# 1  Software and applications developers and analysts
# 2                 Database and network professionals
# 3  Information and communications technology oper...
# 4    Telecommunications and broadcasting technicians
# 5  Electronics and telecommunications installers ...
# 6  Other information and communications technolog...
# 📌 unit — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              PC
# 📌 Unit of measure — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0      Percentage
# 📌 geo — 33 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              AT
# 1              BE
# 2              BG
# 3              CH
# 4              CY
# 5              CZ
# 6              DE
# 7              DK
# 8              EE
# 9              EL
# 📌 Geopolitical entity (reporting) — 33 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0         Austria
# 1         Belgium
# 2        Bulgaria
# 3     Switzerland
# 4          Cyprus
# 5         Czechia
# 6         Germany
# 7         Denmark
# 8         Estonia
# 9          Greece
# 📌 TIME_PERIOD — 23 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0         2019-Q4
# 1         2020-Q1
# 2         2020-Q2
# 3         2020-Q3
# 4         2020-Q4
# 5         2021-Q1
# 6         2021-Q2
# 7         2021-Q3
# 8         2021-Q4
# 9         2022-Q1
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - OBS_VALUE: 692 (15.27%)
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df3)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#   STRUCTURE               STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
# 1  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
# 2  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
# 3  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
# 4  dataflow  ESTAT:ISOC_SKE_ITSPE(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Enterprises that employ ICT specialists by siz...    A         Annual
# 1  Enterprises that employ ICT specialists by siz...    A         Annual
# 2  Enterprises that employ ICT specialists by siz...    A         Annual
# 3  Enterprises that employ ICT specialists by siz...    A         Annual
# 4  Enterprises that employ ICT specialists by siz...    A         Annual
#
#   size_emp Size classes in number of persons employed       nace_r2  \
# 0      0-9               From 0 to 9 persons employed  C10-S951_X_K
# 1      0-9               From 0 to 9 persons employed  C10-S951_X_K
# 2      0-9               From 0 to 9 persons employed  C10-S951_X_K
# 3      0-9               From 0 to 9 persons employed  C10-S951_X_K
# 4      0-9               From 0 to 9 persons employed  C10-S951_X_K
#
#   Statistical classification of economic activities in the European Community (NACE Rev. 2)  \
# 0  All activities (except agriculture, forestry a...
# 1  All activities (except agriculture, forestry a...
# 2  All activities (except agriculture, forestry a...
# 3  All activities (except agriculture, forestry a...
# 4  All activities (except agriculture, forestry a...
#
#   indic_is                      Information society indicator    unit  \
# 0  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 1  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 2  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 3  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 4  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
#
#              Unit of measure geo Geopolitical entity (reporting)  TIME_PERIOD  \
# 0  Percentage of enterprises  DE                         Germany         2022
# 1  Percentage of enterprises  DE                         Germany         2024
# 2  Percentage of enterprises  ES                           Spain         2017
# 3  Percentage of enterprises  ES                           Spain         2018
# 4  Percentage of enterprises  ES                           Spain         2019
#
#    Time  OBS_VALUE  Observation value OBS_FLAG  \
# 0   NaN       6.33                NaN      NaN
# 1   NaN       7.10                NaN      NaN
# 2   NaN       3.27                NaN      NaN
# 3   NaN       2.89                NaN      NaN
# 4   NaN       2.85                NaN      NaN
#
#   Observation status (Flag) V2 structure  CONF_STATUS  \
# 0                                    NaN          NaN
# 1                                    NaN          NaN
# 2                                    NaN          NaN
# 3                                    NaN          NaN
# 4                                    NaN          NaN
#
#    Confidentiality status (flag)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# Dimensiones: 3253 filas × 23 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3253 entries, 0 to 3252
# Data columns (total 23 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   STRUCTURE                                                                                  3253 non-null   object
#  1   STRUCTURE_ID                                                                               3253 non-null   object
#  2   STRUCTURE_NAME                                                                             3253 non-null   object
#  3   freq                                                                                       3253 non-null   object
#  4   Time frequency                                                                             3253 non-null   object
#  5   size_emp                                                                                   3253 non-null   object
#  6   Size classes in number of persons employed                                                 3253 non-null   object
#  7   nace_r2                                                                                    3253 non-null   object
#  8   Statistical classification of economic activities in the European Community (NACE Rev. 2)  3253 non-null   object
#  9   indic_is                                                                                   3253 non-null   object
#  10  Information society indicator                                                              3253 non-null   object
#  11  unit                                                                                       3253 non-null   object
#  12  Unit of measure                                                                            3253 non-null   object
#  13  geo                                                                                        3253 non-null   object
#  14  Geopolitical entity (reporting)                                                            3253 non-null   object
#  15  TIME_PERIOD                                                                                3253 non-null   int64
#  16  Time                                                                                       0 non-null      float64
#  17  OBS_VALUE                                                                                  3236 non-null   float64
#  18  Observation value                                                                          0 non-null      float64
#  19  OBS_FLAG                                                                                   35 non-null     object
#  20  Observation status (Flag) V2 structure                                                     35 non-null     object
#  21  CONF_STATUS                                                                                0 non-null      float64
#  22  Confidentiality status (flag)                                                              0 non-null      float64
# dtypes: float64(5), int64(1), object(17)
# memory usage: 584.7+ KB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                                                        Tipo  Nulos  % Nulos  \
# Observation value                                   float64   3253   100.00
# CONF_STATUS                                         float64   3253   100.00
# Confidentiality status (flag)                       float64   3253   100.00
# Time                                                float64   3253   100.00
# OBS_FLAG                                             object   3218    98.92
# Observation status (Flag) V2 structure               object   3218    98.92
# OBS_VALUE                                           float64     17     0.52
# Size classes in number of persons employed           object      0     0.00
# size_emp                                             object      0     0.00
# Time frequency                                       object      0     0.00
# freq                                                 object      0     0.00
# STRUCTURE_NAME                                       object      0     0.00
# STRUCTURE_ID                                         object      0     0.00
# STRUCTURE                                            object      0     0.00
# nace_r2                                              object      0     0.00
# Geopolitical entity (reporting)                      object      0     0.00
# geo                                                  object      0     0.00
# Unit of measure                                      object      0     0.00
# unit                                                 object      0     0.00
# Information society indicator                        object      0     0.00
# indic_is                                             object      0     0.00
# Statistical classification of economic activiti...   object      0     0.00
# TIME_PERIOD                                           int64      0     0.00
#
#                                                     Valores Únicos  \
# Observation value                                                0
# CONF_STATUS                                                      0
# Confidentiality status (flag)                                    0
# Time                                                             0
# OBS_FLAG                                                         2
# Observation status (Flag) V2 structure                           2
# OBS_VALUE                                                     2217
# Size classes in number of persons employed                      11
# size_emp                                                        11
# Time frequency                                                   1
# freq                                                             1
# STRUCTURE_NAME                                                   1
# STRUCTURE_ID                                                     1
# STRUCTURE                                                        1
# nace_r2                                                          1
# Geopolitical entity (reporting)                                 41
# geo                                                             41
# Unit of measure                                                  2
# unit                                                             2
# Information society indicator                                    1
# indic_is                                                         1
# Statistical classification of economic activiti...               1
# TIME_PERIOD                                                     10
#
#                                                     % Cardinalidad
# Observation value                                             0.00
# CONF_STATUS                                                   0.00
# Confidentiality status (flag)                                 0.00
# Time                                                          0.00
# OBS_FLAG                                                      0.06
# Observation status (Flag) V2 structure                        0.06
# OBS_VALUE                                                    68.15
# Size classes in number of persons employed                    0.34
# size_emp                                                      0.34
# Time frequency                                                0.03
# freq                                                          0.03
# STRUCTURE_NAME                                                0.03
# STRUCTURE_ID                                                  0.03
# STRUCTURE                                                     0.03
# nace_r2                                                       0.03
# Geopolitical entity (reporting)                               1.26
# geo                                                           1.26
# Unit of measure                                               0.06
# unit                                                          0.06
# Information society indicator                                 0.03
# indic_is                                                      0.03
# Statistical classification of economic activiti...            0.03
# TIME_PERIOD                                                   0.31
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - OBS_VALUE (0.52%)
#   🟡 Moderado (5%–20%):
#     - Ninguna
#   🔴 Alto (> 20%):
#     - Observation value (100.00%)
#     - CONF_STATUS (100.00%)
#     - Confidentiality status (flag) (100.00%)
#     - Time (100.00%)
#     - OBS_FLAG (98.92%)
#     - Observation status (Flag) V2 structure (98.92%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
#
# 📌 OBS_FLAG — 🚩 FLAG: nulos_categorica (98.92%)
#           Porcentaje  Recuento
# OBS_FLAG
# NaN            98.92      3218
# b               0.55        18
# u               0.52        17
# 📌 Observation status (Flag) V2 structure — 🚩 FLAG: nulos_categorica (98.92%)
#                                         Porcentaje  Recuento
# Observation status (Flag) V2 structure
# NaN                                          98.92      3218
# break in time series                          0.55        18
# low reliability                               0.52        17
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 Time — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 OBS_VALUE — 🚩 FLAG: nulos_numerica (0.52%)
# 📌 Observation value — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 CONF_STATUS — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 Confidentiality status (flag) — 🚩 FLAG: nulos_numerica (100.00%)
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#                                 count         mean        std      min  \
# TIME_PERIOD                    3253.0  2016.916077   3.151860  2012.00
# Time                              0.0          NaN        NaN      NaN
# OBS_VALUE                      3236.0    33.706595  23.704254     1.13
# Observation value                 0.0          NaN        NaN      NaN
# CONF_STATUS                       0.0          NaN        NaN      NaN
# Confidentiality status (flag)     0.0          NaN        NaN      NaN
#
#                                      25%       50%        75%      max
# TIME_PERIOD                    2015.0000  2017.000  2019.0000  2024.00
# Time                                 NaN       NaN        NaN      NaN
# OBS_VALUE                        16.6975    23.405    46.2475    92.38
# Observation value                    NaN       NaN        NaN      NaN
# CONF_STATUS                          NaN       NaN        NaN      NaN
# Confidentiality status (flag)        NaN       NaN        NaN      NaN
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#                                                    count unique  \
# STRUCTURE                                           3253      1
# STRUCTURE_ID                                        3253      1
# STRUCTURE_NAME                                      3253      1
# freq                                                3253      1
# Time frequency                                      3253      1
# size_emp                                            3253     11
# Size classes in number of persons employed          3253     11
# nace_r2                                             3253      1
# Statistical classification of economic activiti...  3253      1
# indic_is                                            3253      1
# Information society indicator                       3253      1
# unit                                                3253      2
# Unit of measure                                     3253      2
# geo                                                 3253     41
# Geopolitical entity (reporting)                     3253     41
# OBS_FLAG                                              35      2
# Observation status (Flag) V2 structure                35      2
#
#                                                                                                   top  \
# STRUCTURE                                                                                    dataflow
# STRUCTURE_ID                                                                ESTAT:ISOC_SKE_ITSPE(1.0)
# STRUCTURE_NAME                                      Enterprises that employ ICT specialists by siz...
# freq                                                                                                A
# Time frequency                                                                                 Annual
# size_emp                                                                                         GE10
# Size classes in number of persons employed                                10 persons employed or more
# nace_r2                                                                                  C10-S951_X_K
# Statistical classification of economic activiti...  All activities (except agriculture, forestry a...
# indic_is                                                                                      E_ITSP2
# Information society indicator                       Enterprise employed ICT/IT specialists (reduce...
# unit                                                                                           PC_ENT
# Unit of measure                                                             Percentage of enterprises
# geo                                                                                                PT
# Geopolitical entity (reporting)                                                              Portugal
# OBS_FLAG                                                                                            b
# Observation status (Flag) V2 structure                                           break in time series
#
#                                                     freq
# STRUCTURE                                           3253
# STRUCTURE_ID                                        3253
# STRUCTURE_NAME                                      3253
# freq                                                3253
# Time frequency                                      3253
# size_emp                                             619
# Size classes in number of persons employed           619
# nace_r2                                             3253
# Statistical classification of economic activiti...  3253
# indic_is                                            3253
# Information society indicator                       3253
# unit                                                1911
# Unit of measure                                     1911
# geo                                                  116
# Geopolitical entity (reporting)                      116
# OBS_FLAG                                              18
# Observation status (Flag) V2 structure                18
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 STRUCTURE — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0        dataflow
# 📌 STRUCTURE_ID — 1 valores únicos (mostrando hasta 10)
#              Valor (muestra)
# 0  ESTAT:ISOC_SKE_ITSPE(1.0)
# 📌 STRUCTURE_NAME — 1 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  Enterprises that employ ICT specialists by siz...
# 📌 freq — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               A
# 📌 Time frequency — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Annual
# 📌 size_emp — 11 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0             0-9
# 1             0_1
# 2             1-4
# 3             1-9
# 4          10-249
# 5           10-49
# 6             2-9
# 7             5-9
# 8          50-249
# 9            GE10
# 📌 Size classes in number of persons employed — 11 valores únicos (mostrando hasta 10)
#                    Valor (muestra)
# 0     From 0 to 9 persons employed
# 1      From 0 to 1 person employed
# 2     From 1 to 4 persons employed
# 3     From 1 to 9 persons employed
# 4  From 10 to 249 persons employed
# 5   From 10 to 49 persons employed
# 6     From 2 to 9 persons employed
# 7     From 5 to 9 persons employed
# 8  From 50 to 249 persons employed
# 9      10 persons employed or more
# 📌 nace_r2 — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0    C10-S951_X_K
# 📌 Statistical classification of economic activities in the European Community (NACE Rev. 2) — 1 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  All activities (except agriculture, forestry a...
# 📌 indic_is — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0         E_ITSP2
# 📌 Information society indicator — 1 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  Enterprise employed ICT/IT specialists (reduce...
# 📌 unit — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          PC_ENT
# 1     PC_ENT_CUSE
# 📌 Unit of measure — 2 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0                          Percentage of enterprises
# 1  Percentage of the enterprises which use a comp...
# 📌 geo — 41 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              DE
# 1              ES
# 2              PT
# 3              SE
# 4              SK
# 5              UK
# 6              AL
# 7              AT
# 8              BA
# 9              BE
# 📌 Geopolitical entity (reporting) — 41 valores únicos (mostrando hasta 10)
#           Valor (muestra)
# 0                 Germany
# 1                   Spain
# 2                Portugal
# 3                  Sweden
# 4                Slovakia
# 5          United Kingdom
# 6                 Albania
# 7                 Austria
# 8  Bosnia and Herzegovina
# 9                 Belgium
# 📌 OBS_FLAG — 3 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               b
# 1               u
# 📌 Observation status (Flag) V2 structure — 3 valores únicos (mostrando hasta 10)
#         Valor (muestra)
# 0  break in time series
# 1       low reliability
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - OBS_VALUE: 2 (0.06%)
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df4)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#    country currency                role  salary_min  salary_max
# 0  Austria      EUR        Data Analyst       35000       70000
# 1  Austria      EUR      Data Scientist       37000       85000
# 2  Austria      EUR    Business Analyst       35000       75000
# 3  Austria      EUR  IT Project Manager       40000       90000
# 4  Belgium      EUR        Data Analyst       35000       60000
# Dimensiones: 120 filas × 5 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     120 non-null    object
#  1   currency    120 non-null    object
#  2   role        120 non-null    object
#  3   salary_min  120 non-null    int64
#  4   salary_max  120 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 4.8+ KB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#               Tipo  Nulos  % Nulos  Valores Únicos  % Cardinalidad
# country     object      0      0.0              30           25.00
# currency    object      0      0.0               4            3.33
# role        object      0      0.0               4            3.33
# salary_min   int64      0      0.0              20           16.67
# salary_max   int64      0      0.0              23           19.17
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - Ninguna
#   🟡 Moderado (5%–20%):
#     - Ninguna
#   🔴 Alto (> 20%):
#     - Ninguna
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
# No hay variables categóricas con nulos.
#
# 📊 NULOS EN VARIABLES NUMÉRICAS
# No hay variables numéricas con nulos.
#
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#             count          mean            std      min      25%      50%  \
# salary_min  120.0  56750.000000  100973.018278  15000.0  30000.0  35000.0
# salary_max  120.0  92541.666667  152956.845445  30000.0  50000.0  62500.0
#
#                 75%        max
# salary_min  46250.0   700000.0
# salary_max  80000.0  1000000.0
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#          count unique           top freq
# country    120     30       Austria    4
# currency   120      4           EUR  108
# role       120      4  Data Analyst   30
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 country — 30 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0         Austria
# 1         Belgium
# 2        Bulgaria
# 3         Croatia
# 4          Cyprus
# 5         Czechia
# 6         Denmark
# 7         Estonia
# 8         Finland
# 9          France
# 📌 currency — 4 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0             EUR
# 1             CHF
# 2             NOK
# 3             GBP
# 📌 role — 4 valores únicos (mostrando hasta 10)
#       Valor (muestra)
# 0        Data Analyst
# 1      Data Scientist
# 2    Business Analyst
# 3  IT Project Manager
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - salary_min: 7 (5.83%)
# 🚩 FLAG: outliers - salary_max: 6 (5.00%)
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df5)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#   STRUCTURE             STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
# 1  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
# 2  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
# 3  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
# 4  dataflow  ESTAT:ISOC_SK_OJA1(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency unit  \
# 0  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
# 1  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
# 2  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
# 3  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
# 4  Labour market demand for ICT specialists in on...    Q      Quarterly   PC
#
#   Unit of measure geo Geopolitical entity (reporting) TIME_PERIOD  Time  \
# 0      Percentage  AT                         Austria     2019-Q4   NaN
# 1      Percentage  AT                         Austria     2020-Q1   NaN
# 2      Percentage  AT                         Austria     2020-Q2   NaN
# 3      Percentage  AT                         Austria     2020-Q3   NaN
# 4      Percentage  AT                         Austria     2020-Q4   NaN
#
#    OBS_VALUE  Observation value  OBS_FLAG  \
# 0       11.9                NaN       NaN
# 1       12.0                NaN       NaN
# 2       12.9                NaN       NaN
# 3       13.6                NaN       NaN
# 4       14.8                NaN       NaN
#
#    Observation status (Flag) V2 structure  CONF_STATUS  \
# 0                                     NaN          NaN
# 1                                     NaN          NaN
# 2                                     NaN          NaN
# 3                                     NaN          NaN
# 4                                     NaN          NaN
#
#    Confidentiality status (flag)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# Dimensiones: 7239 filas × 17 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7239 entries, 0 to 7238
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STRUCTURE                               7239 non-null   object
#  1   STRUCTURE_ID                            7239 non-null   object
#  2   STRUCTURE_NAME                          7239 non-null   object
#  3   freq                                    7239 non-null   object
#  4   Time frequency                          7239 non-null   object
#  5   unit                                    7239 non-null   object
#  6   Unit of measure                         7239 non-null   object
#  7   geo                                     7239 non-null   object
#  8   Geopolitical entity (reporting)         7239 non-null   object
#  9   TIME_PERIOD                             7239 non-null   object
#  10  Time                                    0 non-null      float64
#  11  OBS_VALUE                               7239 non-null   float64
#  12  Observation value                       0 non-null      float64
#  13  OBS_FLAG                                0 non-null      float64
#  14  Observation status (Flag) V2 structure  0 non-null      float64
#  15  CONF_STATUS                             0 non-null      float64
#  16  Confidentiality status (flag)           0 non-null      float64
# dtypes: float64(7), object(10)
# memory usage: 961.6+ KB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                                            Tipo  Nulos  % Nulos  \
# OBS_FLAG                                float64   7239    100.0
# Observation value                       float64   7239    100.0
# Observation status (Flag) V2 structure  float64   7239    100.0
# Confidentiality status (flag)           float64   7239    100.0
# CONF_STATUS                             float64   7239    100.0
# Time                                    float64   7239    100.0
# STRUCTURE                                object      0      0.0
# STRUCTURE_ID                             object      0      0.0
# STRUCTURE_NAME                           object      0      0.0
# Geopolitical entity (reporting)          object      0      0.0
# geo                                      object      0      0.0
# Unit of measure                          object      0      0.0
# unit                                     object      0      0.0
# Time frequency                           object      0      0.0
# freq                                     object      0      0.0
# OBS_VALUE                               float64      0      0.0
# TIME_PERIOD                              object      0      0.0
#
#                                         Valores Únicos  % Cardinalidad
# OBS_FLAG                                             0            0.00
# Observation value                                    0            0.00
# Observation status (Flag) V2 structure               0            0.00
# Confidentiality status (flag)                        0            0.00
# CONF_STATUS                                          0            0.00
# Time                                                 0            0.00
# STRUCTURE                                            1            0.01
# STRUCTURE_ID                                         1            0.01
# STRUCTURE_NAME                                       1            0.01
# Geopolitical entity (reporting)                    328            4.53
# geo                                                331            4.57
# Unit of measure                                      1            0.01
# unit                                                 1            0.01
# Time frequency                                       1            0.01
# freq                                                 1            0.01
# OBS_VALUE                                          239            3.30
# TIME_PERIOD                                         23            0.32
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - Ninguna
#   🟡 Moderado (5%–20%):
#     - Ninguna
#   🔴 Alto (> 20%):
#     - OBS_FLAG (100.00%)
#     - Observation value (100.00%)
#     - Observation status (Flag) V2 structure (100.00%)
#     - Confidentiality status (flag) (100.00%)
#     - CONF_STATUS (100.00%)
#     - Time (100.00%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
# No hay variables categóricas con nulos.
#
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 Time — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 Observation value — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 OBS_FLAG — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 Observation status (Flag) V2 structure — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 CONF_STATUS — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 Confidentiality status (flag) — 🚩 FLAG: nulos_numerica (100.00%)
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#                                          count      mean       std  min  25%  \
# Time                                       0.0       NaN       NaN  NaN  NaN
# OBS_VALUE                               7239.0  8.920984  4.169902  0.0  6.0
# Observation value                          0.0       NaN       NaN  NaN  NaN
# OBS_FLAG                                   0.0       NaN       NaN  NaN  NaN
# Observation status (Flag) V2 structure     0.0       NaN       NaN  NaN  NaN
# CONF_STATUS                                0.0       NaN       NaN  NaN  NaN
# Confidentiality status (flag)              0.0       NaN       NaN  NaN  NaN
#
#                                         50%   75%   max
# Time                                    NaN   NaN   NaN
# OBS_VALUE                               8.4  11.4  46.3
# Observation value                       NaN   NaN   NaN
# OBS_FLAG                                NaN   NaN   NaN
# Observation status (Flag) V2 structure  NaN   NaN   NaN
# CONF_STATUS                             NaN   NaN   NaN
# Confidentiality status (flag)           NaN   NaN   NaN
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#                                 count unique  \
# STRUCTURE                        7239      1
# STRUCTURE_ID                     7239      1
# STRUCTURE_NAME                   7239      1
# freq                             7239      1
# Time frequency                   7239      1
# unit                             7239      1
# Unit of measure                  7239      1
# geo                              7239    331
# Geopolitical entity (reporting)  7239    328
# TIME_PERIOD                      7239     23
#
#                                                                                top  \
# STRUCTURE                                                                 dataflow
# STRUCTURE_ID                                               ESTAT:ISOC_SK_OJA1(1.0)
# STRUCTURE_NAME                   Labour market demand for ICT specialists in on...
# freq                                                                             Q
# Time frequency                                                           Quarterly
# unit                                                                            PC
# Unit of measure                                                         Percentage
# geo                                                                           UKN0
# Geopolitical entity (reporting)                                         Luxembourg
# TIME_PERIOD                                                                2023-Q4
#
#                                  freq
# STRUCTURE                        7239
# STRUCTURE_ID                     7239
# STRUCTURE_NAME                   7239
# freq                             7239
# Time frequency                   7239
# unit                             7239
# Unit of measure                  7239
# geo                                23
# Geopolitical entity (reporting)    46
# TIME_PERIOD                       330
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 STRUCTURE — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0        dataflow
# 📌 STRUCTURE_ID — 1 valores únicos (mostrando hasta 10)
#            Valor (muestra)
# 0  ESTAT:ISOC_SK_OJA1(1.0)
# 📌 STRUCTURE_NAME — 1 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  Labour market demand for ICT specialists in on...
# 📌 freq — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               Q
# 📌 Time frequency — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0       Quarterly
# 📌 unit — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              PC
# 📌 Unit of measure — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0      Percentage
# 📌 geo — 331 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              AT
# 1            AT11
# 2            AT12
# 3            AT13
# 4            AT21
# 5            AT22
# 6            AT31
# 7            AT32
# 8            AT33
# 9            AT34
# 📌 Geopolitical entity (reporting) — 328 valores únicos (mostrando hasta 10)
#     Valor (muestra)
# 0           Austria
# 1        Burgenland
# 2  Niederösterreich
# 3              Wien
# 4           Kärnten
# 5        Steiermark
# 6    Oberösterreich
# 7          Salzburg
# 8             Tirol
# 9        Vorarlberg
# 📌 TIME_PERIOD — 23 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0         2019-Q4
# 1         2020-Q1
# 2         2020-Q2
# 3         2020-Q3
# 4         2020-Q4
# 5         2021-Q1
# 6         2021-Q2
# 7         2021-Q3
# 8         2021-Q4
# 9         2022-Q1
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - OBS_VALUE: 80 (1.11%)
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df6)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#   STRUCTURE               STRUCTURE_ID                   STRUCTURE_NAME freq  \
# 0  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
# 1  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
# 2  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
# 3  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
# 4  dataflow  ESTAT:ISOC_SKS_ITSPA(1.0)  Employed ICT specialists by age    A
#
#   Time frequency unit Unit of measure     age            Age class geo  \
# 0         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
# 1         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
# 2         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
# 3         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
# 4         Annual   PC      Percentage  Y15-34  From 15 to 34 years  AT
#
#   Geopolitical entity (reporting)  TIME_PERIOD  Time  OBS_VALUE  \
# 0                         Austria         2004   NaN       48.4
# 1                         Austria         2005   NaN       49.2
# 2                         Austria         2006   NaN       48.0
# 3                         Austria         2007   NaN       47.3
# 4                         Austria         2008   NaN       48.5
#
#    Observation value OBS_FLAG Observation status (Flag) V2 structure  \
# 0                NaN       be        break in time series, estimated
# 1                NaN       be        break in time series, estimated
# 2                NaN        e                              estimated
# 3                NaN       be        break in time series, estimated
# 4                NaN        e                              estimated
#
#    CONF_STATUS  Confidentiality status (flag)
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          NaN                            NaN
# Dimensiones: 2752 filas × 19 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 19 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STRUCTURE                               2752 non-null   object
#  1   STRUCTURE_ID                            2752 non-null   object
#  2   STRUCTURE_NAME                          2752 non-null   object
#  3   freq                                    2752 non-null   object
#  4   Time frequency                          2752 non-null   object
#  5   unit                                    2752 non-null   object
#  6   Unit of measure                         2752 non-null   object
#  7   age                                     2752 non-null   object
#  8   Age class                               2752 non-null   object
#  9   geo                                     2752 non-null   object
#  10  Geopolitical entity (reporting)         2752 non-null   object
#  11  TIME_PERIOD                             2752 non-null   int64
#  12  Time                                    0 non-null      float64
#  13  OBS_VALUE                               2752 non-null   float64
#  14  Observation value                       0 non-null      float64
#  15  OBS_FLAG                                2118 non-null   object
#  16  Observation status (Flag) V2 structure  2118 non-null   object
#  17  CONF_STATUS                             0 non-null      float64
#  18  Confidentiality status (flag)           0 non-null      float64
# dtypes: float64(5), int64(1), object(13)
# memory usage: 408.6+ KB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                                            Tipo  Nulos  % Nulos  \
# Observation value                       float64   2752   100.00
# CONF_STATUS                             float64   2752   100.00
# Confidentiality status (flag)           float64   2752   100.00
# Time                                    float64   2752   100.00
# OBS_FLAG                                 object    634    23.04
# Observation status (Flag) V2 structure   object    634    23.04
# STRUCTURE                                object      0     0.00
# STRUCTURE_NAME                           object      0     0.00
# STRUCTURE_ID                             object      0     0.00
# freq                                     object      0     0.00
# Time frequency                           object      0     0.00
# Geopolitical entity (reporting)          object      0     0.00
# geo                                      object      0     0.00
# Age class                                object      0     0.00
# age                                      object      0     0.00
# Unit of measure                          object      0     0.00
# unit                                     object      0     0.00
# OBS_VALUE                               float64      0     0.00
# TIME_PERIOD                               int64      0     0.00
#
#                                         Valores Únicos  % Cardinalidad
# Observation value                                    0            0.00
# CONF_STATUS                                          0            0.00
# Confidentiality status (flag)                        0            0.00
# Time                                                 0            0.00
# OBS_FLAG                                             8            0.29
# Observation status (Flag) V2 structure               8            0.29
# STRUCTURE                                            1            0.04
# STRUCTURE_NAME                                       1            0.04
# STRUCTURE_ID                                         1            0.04
# freq                                                 1            0.04
# Time frequency                                       1            0.04
# Geopolitical entity (reporting)                     37            1.34
# geo                                                 37            1.34
# Age class                                            2            0.07
# age                                                  2            0.07
# Unit of measure                                      2            0.07
# unit                                                 2            0.07
# OBS_VALUE                                         1202           43.68
# TIME_PERIOD                                         21            0.76
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - Ninguna
#   🟡 Moderado (5%–20%):
#     - Ninguna
#   🔴 Alto (> 20%):
#     - Observation value (100.00%)
#     - CONF_STATUS (100.00%)
#     - Confidentiality status (flag) (100.00%)
#     - Time (100.00%)
#     - OBS_FLAG (23.04%)
#     - Observation status (Flag) V2 structure (23.04%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
#
# 📌 OBS_FLAG — 🚩 FLAG: nulos_categorica (23.04%)
#           Porcentaje  Recuento
# OBS_FLAG
# e              54.29      1494
# NaN            23.04       634
# be             14.17       390
# b               5.74       158
# u               1.02        28
# d               0.80        22
# bu              0.58        16
# bd              0.29         8
# de              0.07         2
# 📌 Observation status (Flag) V2 structure — 🚩 FLAG: nulos_categorica (23.04%)
#                                                     Porcentaje  Recuento
# Observation status (Flag) V2 structure
# estimated                                                54.29      1494
# NaN                                                      23.04       634
# break in time series, estimated                          14.17       390
# break in time series                                      5.74       158
# low reliability                                           1.02        28
# definition differs (see metadata)                         0.80        22
# break in time series, low reliability                     0.58        16
# break in time series, definition differs (see m...        0.29         8
# definition differs (see metadata), estimated              0.07         2
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 Time — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 Observation value — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 CONF_STATUS — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 Confidentiality status (flag) — 🚩 FLAG: nulos_numerica (100.00%)
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#                                 count         mean         std     min  \
# TIME_PERIOD                    2752.0  2014.484012    5.889300  2004.0
# Time                              0.0          NaN         NaN     NaN
# OBS_VALUE                      2752.0   145.033576  477.268598     1.5
# Observation value                 0.0          NaN         NaN     NaN
# CONF_STATUS                       0.0          NaN         NaN     NaN
# Confidentiality status (flag)     0.0          NaN         NaN     NaN
#
#                                   25%     50%     75%     max
# TIME_PERIOD                    2010.0  2015.0  2019.0  2024.0
# Time                              NaN     NaN     NaN     NaN
# OBS_VALUE                        36.4    52.7    70.3  6454.1
# Observation value                 NaN     NaN     NaN     NaN
# CONF_STATUS                       NaN     NaN     NaN     NaN
# Confidentiality status (flag)     NaN     NaN     NaN     NaN
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#                                        count unique  \
# STRUCTURE                               2752      1
# STRUCTURE_ID                            2752      1
# STRUCTURE_NAME                          2752      1
# freq                                    2752      1
# Time frequency                          2752      1
# unit                                    2752      2
# Unit of measure                         2752      2
# age                                     2752      2
# Age class                               2752      2
# geo                                     2752     37
# Geopolitical entity (reporting)         2752     37
# OBS_FLAG                                2118      8
# Observation status (Flag) V2 structure  2118      8
#
#                                                                     top  freq
# STRUCTURE                                                      dataflow  2752
# STRUCTURE_ID                                  ESTAT:ISOC_SKS_ITSPA(1.0)  2752
# STRUCTURE_NAME                          Employed ICT specialists by age  2752
# freq                                                                  A  2752
# Time frequency                                                   Annual  2752
# unit                                                                 PC  1376
# Unit of measure                                              Percentage  1376
# age                                                              Y15-34  1376
# Age class                                           From 15 to 34 years  1376
# geo                                                                  AT    84
# Geopolitical entity (reporting)                                 Austria    84
# OBS_FLAG                                                              e  1494
# Observation status (Flag) V2 structure                        estimated  1494
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 STRUCTURE — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0        dataflow
# 📌 STRUCTURE_ID — 1 valores únicos (mostrando hasta 10)
#              Valor (muestra)
# 0  ESTAT:ISOC_SKS_ITSPA(1.0)
# 📌 STRUCTURE_NAME — 1 valores únicos (mostrando hasta 10)
#                    Valor (muestra)
# 0  Employed ICT specialists by age
# 📌 freq — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               A
# 📌 Time frequency — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Annual
# 📌 unit — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              PC
# 1         THS_PER
# 📌 Unit of measure — 2 valores únicos (mostrando hasta 10)
#     Valor (muestra)
# 0        Percentage
# 1  Thousand persons
# 📌 age — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Y15-34
# 1          Y35-74
# 📌 Age class — 2 valores únicos (mostrando hasta 10)
#        Valor (muestra)
# 0  From 15 to 34 years
# 1  From 35 to 74 years
# 📌 geo — 37 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              AT
# 1              BA
# 2              BE
# 3              BG
# 4              CH
# 5              CY
# 6              CZ
# 7              DE
# 8              DK
# 9              EE
# 📌 Geopolitical entity (reporting) — 37 valores únicos (mostrando hasta 10)
#           Valor (muestra)
# 0                 Austria
# 1  Bosnia and Herzegovina
# 2                 Belgium
# 3                Bulgaria
# 4             Switzerland
# 5                  Cyprus
# 6                 Czechia
# 7                 Germany
# 8                 Denmark
# 9                 Estonia
# 📌 OBS_FLAG — 9 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              be
# 1               e
# 2               b
# 3               u
# 4              bd
# 5               d
# 6              bu
# 7              de
# 📌 Observation status (Flag) V2 structure — 9 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0                    break in time series, estimated
# 1                                          estimated
# 2                               break in time series
# 3                                    low reliability
# 4  break in time series, definition differs (see ...
# 5                  definition differs (see metadata)
# 6              break in time series, low reliability
# 7       definition differs (see metadata), estimated
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - OBS_VALUE: 405 (14.72%)
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df7)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#   STRUCTURE               STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
# 1  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
# 2  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
# 3  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
# 4  dataflow  ESTAT:ISOC_SKS_ITSPE(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency unit  \
# 0  Employed ICT specialists by educational attain...    A         Annual   PC
# 1  Employed ICT specialists by educational attain...    A         Annual   PC
# 2  Employed ICT specialists by educational attain...    A         Annual   PC
# 3  Employed ICT specialists by educational attain...    A         Annual   PC
# 4  Employed ICT specialists by educational attain...    A         Annual   PC
#
#   Unit of measure isced11  \
# 0      Percentage   ED0-4
# 1      Percentage   ED0-4
# 2      Percentage   ED0-4
# 3      Percentage   ED0-4
# 4      Percentage   ED0-4
#
#   International Standard Classification of Education (ISCED 2011) geo  \
# 0  Less than primary, primary, secondary and post...               AT
# 1  Less than primary, primary, secondary and post...               AT
# 2  Less than primary, primary, secondary and post...               AT
# 3  Less than primary, primary, secondary and post...               AT
# 4  Less than primary, primary, secondary and post...               AT
#
#   Geopolitical entity (reporting)  TIME_PERIOD  Time  OBS_VALUE  \
# 0                         Austria         2004   NaN       63.2
# 1                         Austria         2005   NaN       66.0
# 2                         Austria         2006   NaN       64.9
# 3                         Austria         2007   NaN       63.4
# 4                         Austria         2008   NaN       67.1
#
#    Observation value OBS_FLAG Observation status (Flag) V2 structure  \
# 0                NaN       be        break in time series, estimated
# 1                NaN       be        break in time series, estimated
# 2                NaN       be        break in time series, estimated
# 3                NaN       be        break in time series, estimated
# 4                NaN        e                              estimated
#
#    CONF_STATUS  Confidentiality status (flag)
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          NaN                            NaN
# Dimensiones: 3146 filas × 19 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3146 entries, 0 to 3145
# Data columns (total 19 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   STRUCTURE                                                        3146 non-null   object
#  1   STRUCTURE_ID                                                     3146 non-null   object
#  2   STRUCTURE_NAME                                                   3146 non-null   object
#  3   freq                                                             3146 non-null   object
#  4   Time frequency                                                   3146 non-null   object
#  5   unit                                                             3146 non-null   object
#  6   Unit of measure                                                  3146 non-null   object
#  7   isced11                                                          3146 non-null   object
#  8   International Standard Classification of Education (ISCED 2011)  3146 non-null   object
#  9   geo                                                              3146 non-null   object
#  10  Geopolitical entity (reporting)                                  3146 non-null   object
#  11  TIME_PERIOD                                                      3146 non-null   int64
#  12  Time                                                             0 non-null      float64
#  13  OBS_VALUE                                                        2910 non-null   float64
#  14  Observation value                                                0 non-null      float64
#  15  OBS_FLAG                                                         2636 non-null   object
#  16  Observation status (Flag) V2 structure                           2636 non-null   object
#  17  CONF_STATUS                                                      0 non-null      float64
#  18  Confidentiality status (flag)                                    0 non-null      float64
# dtypes: float64(5), int64(1), object(13)
# memory usage: 467.1+ KB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                                                        Tipo  Nulos  % Nulos  \
# Observation value                                   float64   3146   100.00
# CONF_STATUS                                         float64   3146   100.00
# Confidentiality status (flag)                       float64   3146   100.00
# Time                                                float64   3146   100.00
# OBS_FLAG                                             object    510    16.21
# Observation status (Flag) V2 structure               object    510    16.21
# OBS_VALUE                                           float64    236     7.50
# STRUCTURE_NAME                                       object      0     0.00
# STRUCTURE_ID                                         object      0     0.00
# STRUCTURE                                            object      0     0.00
# freq                                                 object      0     0.00
# Geopolitical entity (reporting)                      object      0     0.00
# geo                                                  object      0     0.00
# International Standard Classification of Educat...   object      0     0.00
# isced11                                              object      0     0.00
# Unit of measure                                      object      0     0.00
# unit                                                 object      0     0.00
# Time frequency                                       object      0     0.00
# TIME_PERIOD                                           int64      0     0.00
#
#                                                     Valores Únicos  \
# Observation value                                                0
# CONF_STATUS                                                      0
# Confidentiality status (flag)                                    0
# Time                                                             0
# OBS_FLAG                                                        11
# Observation status (Flag) V2 structure                          11
# OBS_VALUE                                                     1290
# STRUCTURE_NAME                                                   1
# STRUCTURE_ID                                                     1
# STRUCTURE                                                        1
# freq                                                             1
# Geopolitical entity (reporting)                                 37
# geo                                                             37
# International Standard Classification of Educat...               3
# isced11                                                          3
# Unit of measure                                                  2
# unit                                                             2
# Time frequency                                                   1
# TIME_PERIOD                                                     21
#
#                                                     % Cardinalidad
# Observation value                                             0.00
# CONF_STATUS                                                   0.00
# Confidentiality status (flag)                                 0.00
# Time                                                          0.00
# OBS_FLAG                                                      0.35
# Observation status (Flag) V2 structure                        0.35
# OBS_VALUE                                                    41.00
# STRUCTURE_NAME                                                0.03
# STRUCTURE_ID                                                  0.03
# STRUCTURE                                                     0.03
# freq                                                          0.03
# Geopolitical entity (reporting)                               1.18
# geo                                                           1.18
# International Standard Classification of Educat...            0.10
# isced11                                                       0.10
# Unit of measure                                               0.06
# unit                                                          0.06
# Time frequency                                                0.03
# TIME_PERIOD                                                   0.67
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - Ninguna
#   🟡 Moderado (5%–20%):
#     - OBS_FLAG (16.21%)
#     - Observation status (Flag) V2 structure (16.21%)
#     - OBS_VALUE (7.50%)
#   🔴 Alto (> 20%):
#     - Observation value (100.00%)
#     - CONF_STATUS (100.00%)
#     - Confidentiality status (flag) (100.00%)
#     - Time (100.00%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
#
# 📌 OBS_FLAG — 🚩 FLAG: nulos_categorica (16.21%)
#           Porcentaje  Recuento
# OBS_FLAG
# e              47.81      1504
# be             17.86       562
# NaN            16.21       510
# u               7.88       248
# b               5.47       172
# bu              3.56       112
# d               0.57        18
# de              0.25         8
# bde             0.13         4
# bd              0.13         4
# bdu             0.06         2
# du              0.06         2
# 📌 Observation status (Flag) V2 structure — 🚩 FLAG: nulos_categorica (16.21%)
#                                                     Porcentaje  Recuento
# Observation status (Flag) V2 structure
# estimated                                                47.81      1504
# break in time series, estimated                          17.86       562
# NaN                                                      16.21       510
# low reliability                                           7.88       248
# break in time series                                      5.47       172
# break in time series, low reliability                     3.56       112
# definition differs (see metadata)                         0.57        18
# definition differs (see metadata), estimated              0.25         8
# break in time series, definition differs (see m...        0.13         4
# break in time series, definition differs (see m...        0.13         4
# break in time series, definition differs (see m...        0.06         2
# definition differs (see metadata), low reliability        0.06         2
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 Time — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 OBS_VALUE — 🚩 FLAG: nulos_numerica (7.50%)
# 📌 Observation value — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 CONF_STATUS — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 Confidentiality status (flag) — 🚩 FLAG: nulos_numerica (100.00%)
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#                                 count         mean         std     min  \
# TIME_PERIOD                    3146.0  2014.537190    5.863691  2004.0
# Time                              0.0          NaN         NaN     NaN
# OBS_VALUE                      2910.0   137.473299  466.194142     0.1
# Observation value                 0.0          NaN         NaN     NaN
# CONF_STATUS                       0.0          NaN         NaN     NaN
# Confidentiality status (flag)     0.0          NaN         NaN     NaN
#
#                                   25%     50%     75%     max
# TIME_PERIOD                    2010.0  2015.0  2019.0  2024.0
# Time                              NaN     NaN     NaN     NaN
# OBS_VALUE                        27.5    50.8    73.4  6936.1
# Observation value                 NaN     NaN     NaN     NaN
# CONF_STATUS                       NaN     NaN     NaN     NaN
# Confidentiality status (flag)     NaN     NaN     NaN     NaN
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#                                                    count unique  \
# STRUCTURE                                           3146      1
# STRUCTURE_ID                                        3146      1
# STRUCTURE_NAME                                      3146      1
# freq                                                3146      1
# Time frequency                                      3146      1
# unit                                                3146      2
# Unit of measure                                     3146      2
# isced11                                             3146      3
# International Standard Classification of Educat...  3146      3
# geo                                                 3146     37
# Geopolitical entity (reporting)                     3146     37
# OBS_FLAG                                            2636     11
# Observation status (Flag) V2 structure              2636     11
#
#                                                                                                   top  \
# STRUCTURE                                                                                    dataflow
# STRUCTURE_ID                                                                ESTAT:ISOC_SKS_ITSPE(1.0)
# STRUCTURE_NAME                                      Employed ICT specialists by educational attain...
# freq                                                                                                A
# Time frequency                                                                                 Annual
# unit                                                                                               PC
# Unit of measure                                                                            Percentage
# isced11                                                                                         ED0-4
# International Standard Classification of Educat...  Less than primary, primary, secondary and post...
# geo                                                                                                SE
# Geopolitical entity (reporting)                                                                Sweden
# OBS_FLAG                                                                                            e
# Observation status (Flag) V2 structure                                                      estimated
#
#                                                     freq
# STRUCTURE                                           3146
# STRUCTURE_ID                                        3146
# STRUCTURE_NAME                                      3146
# freq                                                3146
# Time frequency                                      3146
# unit                                                1573
# Unit of measure                                     1573
# isced11                                             1376
# International Standard Classification of Educat...  1376
# geo                                                  126
# Geopolitical entity (reporting)                      126
# OBS_FLAG                                            1504
# Observation status (Flag) V2 structure              1504
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 STRUCTURE — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0        dataflow
# 📌 STRUCTURE_ID — 1 valores únicos (mostrando hasta 10)
#              Valor (muestra)
# 0  ESTAT:ISOC_SKS_ITSPE(1.0)
# 📌 STRUCTURE_NAME — 1 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  Employed ICT specialists by educational attain...
# 📌 freq — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               A
# 📌 Time frequency — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Annual
# 📌 unit — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              PC
# 1         THS_PER
# 📌 Unit of measure — 2 valores únicos (mostrando hasta 10)
#     Valor (muestra)
# 0        Percentage
# 1  Thousand persons
# 📌 isced11 — 3 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0           ED0-4
# 1           ED5-8
# 2             NRP
# 📌 International Standard Classification of Education (ISCED 2011) — 3 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  Less than primary, primary, secondary and post...
# 1                    Tertiary education (levels 5-8)
# 2                                        No response
# 📌 geo — 37 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              AT
# 1              BA
# 2              BE
# 3              BG
# 4              CH
# 5              CY
# 6              CZ
# 7              DE
# 8              DK
# 9              EE
# 📌 Geopolitical entity (reporting) — 37 valores únicos (mostrando hasta 10)
#           Valor (muestra)
# 0                 Austria
# 1  Bosnia and Herzegovina
# 2                 Belgium
# 3                Bulgaria
# 4             Switzerland
# 5                  Cyprus
# 6                 Czechia
# 7                 Germany
# 8                 Denmark
# 9                 Estonia
# 📌 OBS_FLAG — 12 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              be
# 1               e
# 2               b
# 3             bde
# 4              de
# 5               d
# 6               u
# 7              bu
# 8              bd
# 9             bdu
# 📌 Observation status (Flag) V2 structure — 12 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0                    break in time series, estimated
# 1                                          estimated
# 2                               break in time series
# 3  break in time series, definition differs (see ...
# 4       definition differs (see metadata), estimated
# 5                  definition differs (see metadata)
# 6                                    low reliability
# 7              break in time series, low reliability
# 8  break in time series, definition differs (see ...
# 9  break in time series, definition differs (see ...
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - OBS_VALUE: 366 (12.58%)
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df8)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#   STRUCTURE                STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
# 1  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
# 2  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
# 3  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
# 4  dataflow  ESTAT:ISOC_SKS_ITSPN2(1.0)
#
#                                      STRUCTURE_NAME freq Time frequency  \
# 0  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
# 1  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
# 2  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
# 3  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
# 4  Employed ICT specialists by NACE Rev. 2 activity    A         Annual
#
#   nace_r2  \
# 0       A
# 1       A
# 2       A
# 3       A
# 4       A
#
#   Statistical classification of economic activities in the European Community (NACE Rev. 2)  \
# 0                  Agriculture, forestry and fishing
# 1                  Agriculture, forestry and fishing
# 2                  Agriculture, forestry and fishing
# 3                  Agriculture, forestry and fishing
# 4                  Agriculture, forestry and fishing
#
#      unit                 Unit of measure geo Geopolitical entity (reporting)  \
# 0  PC_EMP  Percentage of total employment  AT                         Austria
# 1  PC_EMP  Percentage of total employment  AT                         Austria
# 2  PC_EMP  Percentage of total employment  AT                         Austria
# 3  PC_EMP  Percentage of total employment  AT                         Austria
# 4  PC_EMP  Percentage of total employment  AT                         Austria
#
#    TIME_PERIOD  Time  OBS_VALUE  Observation value OBS_FLAG  \
# 0         2008   NaN        NaN                NaN       bu
# 1         2010   NaN        NaN                NaN        u
# 2         2011   NaN        NaN                NaN       bu
# 3         2012   NaN        NaN                NaN        u
# 4         2013   NaN        NaN                NaN        u
#
#   Observation status (Flag) V2 structure  CONF_STATUS  \
# 0  break in time series, low reliability          NaN
# 1                        low reliability          NaN
# 2  break in time series, low reliability          NaN
# 3                        low reliability          NaN
# 4                        low reliability          NaN
#
#    Confidentiality status (flag)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# Dimensiones: 40900 filas × 19 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40900 entries, 0 to 40899
# Data columns (total 19 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   STRUCTURE                                                                                  40900 non-null  object
#  1   STRUCTURE_ID                                                                               40900 non-null  object
#  2   STRUCTURE_NAME                                                                             40900 non-null  object
#  3   freq                                                                                       40900 non-null  object
#  4   Time frequency                                                                             40900 non-null  object
#  5   nace_r2                                                                                    40900 non-null  object
#  6   Statistical classification of economic activities in the European Community (NACE Rev. 2)  40900 non-null  object
#  7   unit                                                                                       40900 non-null  object
#  8   Unit of measure                                                                            40900 non-null  object
#  9   geo                                                                                        40900 non-null  object
#  10  Geopolitical entity (reporting)                                                            40900 non-null  object
#  11  TIME_PERIOD                                                                                40900 non-null  int64
#  12  Time                                                                                       0 non-null      float64
#  13  OBS_VALUE                                                                                  24052 non-null  float64
#  14  Observation value                                                                          0 non-null      float64
#  15  OBS_FLAG                                                                                   40308 non-null  object
#  16  Observation status (Flag) V2 structure                                                     40308 non-null  object
#  17  CONF_STATUS                                                                                0 non-null      float64
#  18  Confidentiality status (flag)                                                              0 non-null      float64
# dtypes: float64(5), int64(1), object(13)
# memory usage: 5.9+ MB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                                                        Tipo  Nulos  % Nulos  \
# Observation value                                   float64  40900   100.00
# CONF_STATUS                                         float64  40900   100.00
# Confidentiality status (flag)                       float64  40900   100.00
# Time                                                float64  40900   100.00
# OBS_VALUE                                           float64  16848    41.19
# OBS_FLAG                                             object    592     1.45
# Observation status (Flag) V2 structure               object    592     1.45
# STRUCTURE_NAME                                       object      0     0.00
# STRUCTURE_ID                                         object      0     0.00
# STRUCTURE                                            object      0     0.00
# freq                                                 object      0     0.00
# Geopolitical entity (reporting)                      object      0     0.00
# geo                                                  object      0     0.00
# Unit of measure                                      object      0     0.00
# unit                                                 object      0     0.00
# Statistical classification of economic activiti...   object      0     0.00
# nace_r2                                              object      0     0.00
# Time frequency                                       object      0     0.00
# TIME_PERIOD                                           int64      0     0.00
#
#                                                     Valores Únicos  \
# Observation value                                                0
# CONF_STATUS                                                      0
# Confidentiality status (flag)                                    0
# Time                                                             0
# OBS_VALUE                                                     1694
# OBS_FLAG                                                        11
# Observation status (Flag) V2 structure                          11
# STRUCTURE_NAME                                                   1
# STRUCTURE_ID                                                     1
# STRUCTURE                                                        1
# freq                                                             1
# Geopolitical entity (reporting)                                 37
# geo                                                             37
# Unit of measure                                                  2
# unit                                                             2
# Statistical classification of economic activiti...              41
# nace_r2                                                         41
# Time frequency                                                   1
# TIME_PERIOD                                                     17
#
#                                                     % Cardinalidad
# Observation value                                             0.00
# CONF_STATUS                                                   0.00
# Confidentiality status (flag)                                 0.00
# Time                                                          0.00
# OBS_VALUE                                                     4.14
# OBS_FLAG                                                      0.03
# Observation status (Flag) V2 structure                        0.03
# STRUCTURE_NAME                                                0.00
# STRUCTURE_ID                                                  0.00
# STRUCTURE                                                     0.00
# freq                                                          0.00
# Geopolitical entity (reporting)                               0.09
# geo                                                           0.09
# Unit of measure                                               0.00
# unit                                                          0.00
# Statistical classification of economic activiti...            0.10
# nace_r2                                                       0.10
# Time frequency                                                0.00
# TIME_PERIOD                                                   0.04
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - OBS_FLAG (1.45%)
#     - Observation status (Flag) V2 structure (1.45%)
#   🟡 Moderado (5%–20%):
#     - Ninguna
#   🔴 Alto (> 20%):
#     - Observation value (100.00%)
#     - CONF_STATUS (100.00%)
#     - Confidentiality status (flag) (100.00%)
#     - Time (100.00%)
#     - OBS_VALUE (41.19%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
#
# 📌 OBS_FLAG — 🚩 FLAG: nulos_categorica (1.45%)
#           Porcentaje  Recuento
# OBS_FLAG
# u              48.03     19644
# e              27.38     11200
# bu             12.99      5314
# be              8.42      3444
# NaN             1.45       592
# de              0.73       298
# b               0.33       134
# bde             0.24        98
# du              0.22        92
# d               0.10        42
# bdu             0.08        34
# bd              0.02         8
# 📌 Observation status (Flag) V2 structure — 🚩 FLAG: nulos_categorica (1.45%)
#                                                     Porcentaje  Recuento
# Observation status (Flag) V2 structure
# low reliability                                          48.03     19644
# estimated                                                27.38     11200
# break in time series, low reliability                    12.99      5314
# break in time series, estimated                           8.42      3444
# NaN                                                       1.45       592
# definition differs (see metadata), estimated              0.73       298
# break in time series                                      0.33       134
# break in time series, definition differs (see m...        0.24        98
# definition differs (see metadata), low reliability        0.22        92
# definition differs (see metadata)                         0.10        42
# break in time series, definition differs (see m...        0.08        34
# break in time series, definition differs (see m...        0.02         8
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 Time — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 OBS_VALUE — 🚩 FLAG: nulos_numerica (41.19%)
# 📌 Observation value — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 CONF_STATUS — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 Confidentiality status (flag) — 🚩 FLAG: nulos_numerica (100.00%)
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#                                  count         mean         std     min  \
# TIME_PERIOD                    40900.0  2016.259169    4.767308  2008.0
# Time                               0.0          NaN         NaN     NaN
# OBS_VALUE                      24052.0    26.700619  126.824907     0.0
# Observation value                  0.0          NaN         NaN     NaN
# CONF_STATUS                        0.0          NaN         NaN     NaN
# Confidentiality status (flag)      0.0          NaN         NaN     NaN
#
#                                   25%     50%     75%     max
# TIME_PERIOD                    2012.0  2016.0  2020.0  2024.0
# Time                              NaN     NaN     NaN     NaN
# OBS_VALUE                         2.5     5.8    18.2  4905.5
# Observation value                 NaN     NaN     NaN     NaN
# CONF_STATUS                       NaN     NaN     NaN     NaN
# Confidentiality status (flag)     NaN     NaN     NaN     NaN
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#                                                     count unique  \
# STRUCTURE                                           40900      1
# STRUCTURE_ID                                        40900      1
# STRUCTURE_NAME                                      40900      1
# freq                                                40900      1
# Time frequency                                      40900      1
# nace_r2                                             40900     41
# Statistical classification of economic activiti...  40900     41
# unit                                                40900      2
# Unit of measure                                     40900      2
# geo                                                 40900     37
# Geopolitical entity (reporting)                     40900     37
# OBS_FLAG                                            40308     11
# Observation status (Flag) V2 structure              40308     11
#
#                                                                                                   top  \
# STRUCTURE                                                                                    dataflow
# STRUCTURE_ID                                                               ESTAT:ISOC_SKS_ITSPN2(1.0)
# STRUCTURE_NAME                                       Employed ICT specialists by NACE Rev. 2 activity
# freq                                                                                                A
# Time frequency                                                                                 Annual
# nace_r2                                                                                       J58-J60
# Statistical classification of economic activiti...  Publishing, motion picture, video, television ...
# unit                                                                                           PC_EMP
# Unit of measure                                                        Percentage of total employment
# geo                                                                                         EU27_2020
# Geopolitical entity (reporting)                             European Union - 27 countries (from 2020)
# OBS_FLAG                                                                                            u
# Observation status (Flag) V2 structure                                                low reliability
#
#                                                      freq
# STRUCTURE                                           40900
# STRUCTURE_ID                                        40900
# STRUCTURE_NAME                                      40900
# freq                                                40900
# Time frequency                                      40900
# nace_r2                                              1154
# Statistical classification of economic activiti...   1154
# unit                                                20450
# Unit of measure                                     20450
# geo                                                  1394
# Geopolitical entity (reporting)                      1394
# OBS_FLAG                                            19644
# Observation status (Flag) V2 structure              19644
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 STRUCTURE — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0        dataflow
# 📌 STRUCTURE_ID — 1 valores únicos (mostrando hasta 10)
#               Valor (muestra)
# 0  ESTAT:ISOC_SKS_ITSPN2(1.0)
# 📌 STRUCTURE_NAME — 1 valores únicos (mostrando hasta 10)
#                                     Valor (muestra)
# 0  Employed ICT specialists by NACE Rev. 2 activity
# 📌 freq — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               A
# 📌 Time frequency — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Annual
# 📌 nace_r2 — 41 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               A
# 1               B
# 2               C
# 3         C10-C12
# 4         C13-C15
# 5         C16-C18
# 6         C19-C21
# 7         C22_C23
# 8         C24_C25
# 9             C26
# 📌 Statistical classification of economic activities in the European Community (NACE Rev. 2) — 41 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0                  Agriculture, forestry and fishing
# 1                               Mining and quarrying
# 2                                      Manufacturing
# 3  Manufacture of food products; beverages and to...
# 4  Manufacture of textiles, wearing apparel, leat...
# 5  Manufacture of wood, paper, printing and repro...
# 6  Manufacture of coke and refined petroleum prod...
# 7  Manufacture of rubber and plastic products and...
# 8  Manufacture of basic metals and fabricated met...
# 9  Manufacture of computer, electronic and optica...
# 📌 unit — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          PC_EMP
# 1         THS_PER
# 📌 Unit of measure — 2 valores únicos (mostrando hasta 10)
#                   Valor (muestra)
# 0  Percentage of total employment
# 1                Thousand persons
# 📌 geo — 37 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              AT
# 1              BA
# 2              BE
# 3              BG
# 4              CH
# 5              CZ
# 6              DE
# 7              DK
# 8              EE
# 9              EL
# 📌 Geopolitical entity (reporting) — 37 valores únicos (mostrando hasta 10)
#           Valor (muestra)
# 0                 Austria
# 1  Bosnia and Herzegovina
# 2                 Belgium
# 3                Bulgaria
# 4             Switzerland
# 5                 Czechia
# 6                 Germany
# 7                 Denmark
# 8                 Estonia
# 9                  Greece
# 📌 OBS_FLAG — 12 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              bu
# 1               u
# 2             bdu
# 3              du
# 4              be
# 5               e
# 6               b
# 7             bde
# 8              de
# 9              bd
# 📌 Observation status (Flag) V2 structure — 12 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0              break in time series, low reliability
# 1                                    low reliability
# 2  break in time series, definition differs (see ...
# 3  definition differs (see metadata), low reliabi...
# 4                    break in time series, estimated
# 5                                          estimated
# 6                               break in time series
# 7  break in time series, definition differs (see ...
# 8       definition differs (see metadata), estimated
# 9  break in time series, definition differs (see ...
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - OBS_VALUE: 3356 (13.95%)
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df9)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#   STRUCTURE               STRUCTURE_ID                   STRUCTURE_NAME freq  \
# 0  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
# 1  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
# 2  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
# 3  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
# 4  dataflow  ESTAT:ISOC_SKS_ITSPS(1.0)  Employed ICT specialists by sex    A
#
#   Time frequency unit Unit of measure sex      Sex geo  \
# 0         Annual   PC      Percentage   F  Females  AT
# 1         Annual   PC      Percentage   F  Females  AT
# 2         Annual   PC      Percentage   F  Females  AT
# 3         Annual   PC      Percentage   F  Females  AT
# 4         Annual   PC      Percentage   F  Females  AT
#
#   Geopolitical entity (reporting)  TIME_PERIOD  Time  OBS_VALUE  \
# 0                         Austria         2004   NaN       22.1
# 1                         Austria         2005   NaN       20.0
# 2                         Austria         2006   NaN       19.7
# 3                         Austria         2007   NaN       20.9
# 4                         Austria         2008   NaN       17.6
#
#    Observation value OBS_FLAG Observation status (Flag) V2 structure  \
# 0                NaN       be        break in time series, estimated
# 1                NaN       be        break in time series, estimated
# 2                NaN        e                              estimated
# 3                NaN       be        break in time series, estimated
# 4                NaN        e                              estimated
#
#    CONF_STATUS  Confidentiality status (flag)
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          NaN                            NaN
# Dimensiones: 2752 filas × 19 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 19 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STRUCTURE                               2752 non-null   object
#  1   STRUCTURE_ID                            2752 non-null   object
#  2   STRUCTURE_NAME                          2752 non-null   object
#  3   freq                                    2752 non-null   object
#  4   Time frequency                          2752 non-null   object
#  5   unit                                    2752 non-null   object
#  6   Unit of measure                         2752 non-null   object
#  7   sex                                     2752 non-null   object
#  8   Sex                                     2752 non-null   object
#  9   geo                                     2752 non-null   object
#  10  Geopolitical entity (reporting)         2752 non-null   object
#  11  TIME_PERIOD                             2752 non-null   int64
#  12  Time                                    0 non-null      float64
#  13  OBS_VALUE                               2734 non-null   float64
#  14  Observation value                       0 non-null      float64
#  15  OBS_FLAG                                2164 non-null   object
#  16  Observation status (Flag) V2 structure  2164 non-null   object
#  17  CONF_STATUS                             0 non-null      float64
#  18  Confidentiality status (flag)           0 non-null      float64
# dtypes: float64(5), int64(1), object(13)
# memory usage: 408.6+ KB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                                            Tipo  Nulos  % Nulos  \
# Observation value                       float64   2752   100.00
# CONF_STATUS                             float64   2752   100.00
# Confidentiality status (flag)           float64   2752   100.00
# Time                                    float64   2752   100.00
# OBS_FLAG                                 object    588    21.37
# Observation status (Flag) V2 structure   object    588    21.37
# OBS_VALUE                               float64     18     0.65
# STRUCTURE_NAME                           object      0     0.00
# STRUCTURE_ID                             object      0     0.00
# STRUCTURE                                object      0     0.00
# freq                                     object      0     0.00
# Geopolitical entity (reporting)          object      0     0.00
# geo                                      object      0     0.00
# Sex                                      object      0     0.00
# sex                                      object      0     0.00
# Unit of measure                          object      0     0.00
# unit                                     object      0     0.00
# Time frequency                           object      0     0.00
# TIME_PERIOD                               int64      0     0.00
#
#                                         Valores Únicos  % Cardinalidad
# Observation value                                    0            0.00
# CONF_STATUS                                          0            0.00
# Confidentiality status (flag)                        0            0.00
# Time                                                 0            0.00
# OBS_FLAG                                             8            0.29
# Observation status (Flag) V2 structure               8            0.29
# OBS_VALUE                                         1188           43.17
# STRUCTURE_NAME                                       1            0.04
# STRUCTURE_ID                                         1            0.04
# STRUCTURE                                            1            0.04
# freq                                                 1            0.04
# Geopolitical entity (reporting)                     37            1.34
# geo                                                 37            1.34
# Sex                                                  2            0.07
# sex                                                  2            0.07
# Unit of measure                                      2            0.07
# unit                                                 2            0.07
# Time frequency                                       1            0.04
# TIME_PERIOD                                         21            0.76
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - OBS_VALUE (0.65%)
#   🟡 Moderado (5%–20%):
#     - Ninguna
#   🔴 Alto (> 20%):
#     - Observation value (100.00%)
#     - CONF_STATUS (100.00%)
#     - Confidentiality status (flag) (100.00%)
#     - Time (100.00%)
#     - OBS_FLAG (21.37%)
#     - Observation status (Flag) V2 structure (21.37%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
#
# 📌 OBS_FLAG — 🚩 FLAG: nulos_categorica (21.37%)
#           Porcentaje  Recuento
# OBS_FLAG
# e              53.85      1482
# NaN            21.37       588
# be             14.68       404
# b               4.94       136
# u               3.12        86
# bu              0.87        24
# d               0.80        22
# bd              0.29         8
# de              0.07         2
# 📌 Observation status (Flag) V2 structure — 🚩 FLAG: nulos_categorica (21.37%)
#                                                     Porcentaje  Recuento
# Observation status (Flag) V2 structure
# estimated                                                53.85      1482
# NaN                                                      21.37       588
# break in time series, estimated                          14.68       404
# break in time series                                      4.94       136
# low reliability                                           3.12        86
# break in time series, low reliability                     0.87        24
# definition differs (see metadata)                         0.80        22
# break in time series, definition differs (see m...        0.29         8
# definition differs (see metadata), estimated              0.07         2
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 Time — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 OBS_VALUE — 🚩 FLAG: nulos_numerica (0.65%)
# 📌 Observation value — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 CONF_STATUS — 🚩 FLAG: nulos_numerica (100.00%)
# 📌 Confidentiality status (flag) — 🚩 FLAG: nulos_numerica (100.00%)
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#                                 count         mean         std     min  \
# TIME_PERIOD                    2752.0  2014.484012    5.889300  2004.0
# Time                              0.0          NaN         NaN     NaN
# OBS_VALUE                      2734.0   145.989832  552.654822     0.6
# Observation value                 0.0          NaN         NaN     NaN
# CONF_STATUS                       0.0          NaN         NaN     NaN
# Confidentiality status (flag)     0.0          NaN         NaN     NaN
#
#                                     25%     50%     75%     max
# TIME_PERIOD                    2010.000  2015.0  2019.0  2024.0
# Time                                NaN     NaN     NaN     NaN
# OBS_VALUE                        19.125    48.8    84.2  8273.9
# Observation value                   NaN     NaN     NaN     NaN
# CONF_STATUS                         NaN     NaN     NaN     NaN
# Confidentiality status (flag)       NaN     NaN     NaN     NaN
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#                                        count unique  \
# STRUCTURE                               2752      1
# STRUCTURE_ID                            2752      1
# STRUCTURE_NAME                          2752      1
# freq                                    2752      1
# Time frequency                          2752      1
# unit                                    2752      2
# Unit of measure                         2752      2
# sex                                     2752      2
# Sex                                     2752      2
# geo                                     2752     37
# Geopolitical entity (reporting)         2752     37
# OBS_FLAG                                2164      8
# Observation status (Flag) V2 structure  2164      8
#
#                                                                     top  freq
# STRUCTURE                                                      dataflow  2752
# STRUCTURE_ID                                  ESTAT:ISOC_SKS_ITSPS(1.0)  2752
# STRUCTURE_NAME                          Employed ICT specialists by sex  2752
# freq                                                                  A  2752
# Time frequency                                                   Annual  2752
# unit                                                                 PC  1376
# Unit of measure                                              Percentage  1376
# sex                                                                   F  1376
# Sex                                                             Females  1376
# geo                                                                  AT    84
# Geopolitical entity (reporting)                                 Austria    84
# OBS_FLAG                                                              e  1482
# Observation status (Flag) V2 structure                        estimated  1482
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 STRUCTURE — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0        dataflow
# 📌 STRUCTURE_ID — 1 valores únicos (mostrando hasta 10)
#              Valor (muestra)
# 0  ESTAT:ISOC_SKS_ITSPS(1.0)
# 📌 STRUCTURE_NAME — 1 valores únicos (mostrando hasta 10)
#                    Valor (muestra)
# 0  Employed ICT specialists by sex
# 📌 freq — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               A
# 📌 Time frequency — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Annual
# 📌 unit — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              PC
# 1         THS_PER
# 📌 Unit of measure — 2 valores únicos (mostrando hasta 10)
#     Valor (muestra)
# 0        Percentage
# 1  Thousand persons
# 📌 sex — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               F
# 1               M
# 📌 Sex — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0         Females
# 1           Males
# 📌 geo — 37 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              AT
# 1              BA
# 2              BE
# 3              BG
# 4              CH
# 5              CY
# 6              CZ
# 7              DE
# 8              DK
# 9              EE
# 📌 Geopolitical entity (reporting) — 37 valores únicos (mostrando hasta 10)
#           Valor (muestra)
# 0                 Austria
# 1  Bosnia and Herzegovina
# 2                 Belgium
# 3                Bulgaria
# 4             Switzerland
# 5                  Cyprus
# 6                 Czechia
# 7                 Germany
# 8                 Denmark
# 9                 Estonia
# 📌 OBS_FLAG — 9 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              be
# 1               e
# 2               b
# 3              bu
# 4               u
# 5              bd
# 6               d
# 7              de
# 📌 Observation status (Flag) V2 structure — 9 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0                    break in time series, estimated
# 1                                          estimated
# 2                               break in time series
# 3              break in time series, low reliability
# 4                                    low reliability
# 5  break in time series, definition differs (see ...
# 6                  definition differs (see metadata)
# 7       definition differs (see metadata), estimated
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - OBS_VALUE: 289 (10.57%)
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df10)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#                     DATAFLOW        LAST UPDATE    freq  \
# 0  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
# 1  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
# 2  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
# 3  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
# 4  ESTAT:ISOC_SKS_ITSPT(1.0)  14/04/25 23:00:00  Annual
#
#                              unit      geo  TIME_PERIOD  OBS_VALUE OBS_FLAG  \
# 0  Percentage of total employment  Austria         2004        2.9       be
# 1  Percentage of total employment  Austria         2005        3.1       be
# 2  Percentage of total employment  Austria         2006        3.3        e
# 3  Percentage of total employment  Austria         2007        3.3       be
# 4  Percentage of total employment  Austria         2008        3.3        e
#
#    CONF_STATUS
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# Dimensiones: 1376 filas × 9 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1376 entries, 0 to 1375
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATAFLOW     1376 non-null   object
#  1   LAST UPDATE  1376 non-null   object
#  2   freq         1376 non-null   object
#  3   unit         1376 non-null   object
#  4   geo          1376 non-null   object
#  5   TIME_PERIOD  1376 non-null   int64
#  6   OBS_VALUE    1376 non-null   float64
#  7   OBS_FLAG     924 non-null    object
#  8   CONF_STATUS  0 non-null      float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 96.9+ KB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                 Tipo  Nulos  % Nulos  Valores Únicos  % Cardinalidad
# CONF_STATUS  float64   1376   100.00               0            0.00
# OBS_FLAG      object    452    32.85               7            0.51
# DATAFLOW      object      0     0.00               1            0.07
# LAST UPDATE   object      0     0.00               1            0.07
# freq          object      0     0.00               1            0.07
# geo           object      0     0.00              37            2.69
# unit          object      0     0.00               2            0.15
# OBS_VALUE    float64      0     0.00             670           48.69
# TIME_PERIOD    int64      0     0.00              21            1.53
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - Ninguna
#   🟡 Moderado (5%–20%):
#     - Ninguna
#   🔴 Alto (> 20%):
#     - CONF_STATUS (100.00%)
#     - OBS_FLAG (32.85%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
#
# 📌 OBS_FLAG — 🚩 FLAG: nulos_categorica (32.85%)
#           Porcentaje  Recuento
# OBS_FLAG
# e              45.35       624
# NaN            32.85       452
# be             12.79       176
# b               7.56       104
# d               0.87        12
# bd              0.29         4
# bu              0.15         2
# u               0.15         2
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 CONF_STATUS — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#               count         mean         std     min     25%     50%  \
# TIME_PERIOD  1376.0  2014.484012    5.890371  2004.0  2010.0  2015.0
# OBS_VALUE    1376.0   241.470349  934.380745     1.0     3.7     6.8
# CONF_STATUS     0.0          NaN         NaN     NaN     NaN     NaN
#
#                   75%      max
# TIME_PERIOD  2019.000   2024.0
# OBS_VALUE     136.725  10273.6
# CONF_STATUS       NaN      NaN
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#             count unique                             top  freq
# DATAFLOW     1376      1       ESTAT:ISOC_SKS_ITSPT(1.0)  1376
# LAST UPDATE  1376      1               14/04/25 23:00:00  1376
# freq         1376      1                          Annual  1376
# unit         1376      2  Percentage of total employment   688
# geo          1376     37                         Austria    42
# OBS_FLAG      924      7                               e   624
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 DATAFLOW — 1 valores únicos (mostrando hasta 10)
#              Valor (muestra)
# 0  ESTAT:ISOC_SKS_ITSPT(1.0)
# 📌 LAST UPDATE — 1 valores únicos (mostrando hasta 10)
#      Valor (muestra)
# 0  14/04/25 23:00:00
# 📌 freq — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Annual
# 📌 unit — 2 valores únicos (mostrando hasta 10)
#                   Valor (muestra)
# 0  Percentage of total employment
# 1                Thousand persons
# 📌 geo — 37 valores únicos (mostrando hasta 10)
#           Valor (muestra)
# 0                 Austria
# 1  Bosnia and Herzegovina
# 2                 Belgium
# 3                Bulgaria
# 4             Switzerland
# 5                  Cyprus
# 6                 Czechia
# 7                 Germany
# 8                 Denmark
# 9                 Estonia
# 📌 OBS_FLAG — 8 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              be
# 1               e
# 2               b
# 3              bd
# 4               d
# 5              bu
# 6               u
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - OBS_VALUE: 164 (11.92%)
# 🏁 REVISIÓN EDA FINALIZADA

# %%
eda(df11)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Vista inicial (primeras 5 filas):
#   STRUCTURE                 STRUCTURE_ID  \
# 0  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
# 1  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
# 2  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
# 3  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
# 4  dataflow  ESTAT:ISOC_SKE_ITSPEN2(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Enterprises that employ ICT specialists by NAC...    A         Annual
# 1  Enterprises that employ ICT specialists by NAC...    A         Annual
# 2  Enterprises that employ ICT specialists by NAC...    A         Annual
# 3  Enterprises that employ ICT specialists by NAC...    A         Annual
# 4  Enterprises that employ ICT specialists by NAC...    A         Annual
#
#   size_emp Size classes in number of persons employed nace_r2  \
# 0     GE10                10 persons employed or more       C
# 1     GE10                10 persons employed or more       C
# 2     GE10                10 persons employed or more       C
# 3     GE10                10 persons employed or more       C
# 4     GE10                10 persons employed or more       C
#
#   Statistical classification of economic activities in the European Community (NACE Rev. 2)  \
# 0                                      Manufacturing
# 1                                      Manufacturing
# 2                                      Manufacturing
# 3                                      Manufacturing
# 4                                      Manufacturing
#
#   indic_is                      Information society indicator    unit  \
# 0  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 1  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 2  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 3  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
# 4  E_ITSP2  Enterprise employed ICT/IT specialists (reduce...  PC_ENT
#
#              Unit of measure geo Geopolitical entity (reporting)  TIME_PERIOD  \
# 0  Percentage of enterprises  AL                         Albania         2022
# 1  Percentage of enterprises  AT                         Austria         2012
# 2  Percentage of enterprises  AT                         Austria         2014
# 3  Percentage of enterprises  AT                         Austria         2015
# 4  Percentage of enterprises  AT                         Austria         2016
#
#    Time  OBS_VALUE  Observation value OBS_FLAG  \
# 0   NaN      11.22                NaN        b
# 1   NaN      35.12                NaN      NaN
# 2   NaN      31.01                NaN      NaN
# 3   NaN      31.44                NaN      NaN
# 4   NaN      35.22                NaN      NaN
#
#   Observation status (Flag) V2 structure CONF_STATUS  \
# 0                   break in time series         NaN
# 1                                    NaN         NaN
# 2                                    NaN         NaN
# 3                                    NaN         NaN
# 4                                    NaN         NaN
#
#   Confidentiality status (flag)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# Dimensiones: 23180 filas × 23 columnas
#
# Información general (dtypes, nulos, memoria):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23180 entries, 0 to 23179
# Data columns (total 23 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   STRUCTURE                                                                                  23180 non-null  object
#  1   STRUCTURE_ID                                                                               23180 non-null  object
#  2   STRUCTURE_NAME                                                                             23180 non-null  object
#  3   freq                                                                                       23180 non-null  object
#  4   Time frequency                                                                             23180 non-null  object
#  5   size_emp                                                                                   23180 non-null  object
#  6   Size classes in number of persons employed                                                 23180 non-null  object
#  7   nace_r2                                                                                    23180 non-null  object
#  8   Statistical classification of economic activities in the European Community (NACE Rev. 2)  23180 non-null  object
#  9   indic_is                                                                                   23180 non-null  object
#  10  Information society indicator                                                              23180 non-null  object
#  11  unit                                                                                       23180 non-null  object
#  12  Unit of measure                                                                            23180 non-null  object
#  13  geo                                                                                        23180 non-null  object
#  14  Geopolitical entity (reporting)                                                            23180 non-null  object
#  15  TIME_PERIOD                                                                                23180 non-null  int64
#  16  Time                                                                                       0 non-null      float64
#  17  OBS_VALUE                                                                                  20489 non-null  float64
#  18  Observation value                                                                          0 non-null      float64
#  19  OBS_FLAG                                                                                   2609 non-null   object
#  20  Observation status (Flag) V2 structure                                                     2609 non-null   object
#  21  CONF_STATUS                                                                                188 non-null    object
#  22  Confidentiality status (flag)                                                              188 non-null    object
# dtypes: float64(3), int64(1), object(19)
# memory usage: 4.1+ MB
#
# 🚩 FLAG: duplicados - Filas duplicadas: 0 (0.00%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                                                        Tipo  Nulos  % Nulos  \
# Observation value                                   float64  23180   100.00
# Time                                                float64  23180   100.00
# Confidentiality status (flag)                        object  22992    99.19
# CONF_STATUS                                          object  22992    99.19
# OBS_FLAG                                             object  20571    88.74
# Observation status (Flag) V2 structure               object  20571    88.74
# OBS_VALUE                                           float64   2691    11.61
# Size classes in number of persons employed           object      0     0.00
# size_emp                                             object      0     0.00
# Time frequency                                       object      0     0.00
# freq                                                 object      0     0.00
# STRUCTURE_NAME                                       object      0     0.00
# STRUCTURE_ID                                         object      0     0.00
# STRUCTURE                                            object      0     0.00
# nace_r2                                              object      0     0.00
# Geopolitical entity (reporting)                      object      0     0.00
# geo                                                  object      0     0.00
# Unit of measure                                      object      0     0.00
# unit                                                 object      0     0.00
# Information society indicator                        object      0     0.00
# indic_is                                             object      0     0.00
# Statistical classification of economic activiti...   object      0     0.00
# TIME_PERIOD                                           int64      0     0.00
#
#                                                     Valores Únicos  \
# Observation value                                                0
# Time                                                             0
# Confidentiality status (flag)                                    1
# CONF_STATUS                                                      1
# OBS_FLAG                                                         3
# Observation status (Flag) V2 structure                           3
# OBS_VALUE                                                     5659
# Size classes in number of persons employed                       1
# size_emp                                                         1
# Time frequency                                                   1
# freq                                                             1
# STRUCTURE_NAME                                                   1
# STRUCTURE_ID                                                     1
# STRUCTURE                                                        1
# nace_r2                                                         51
# Geopolitical entity (reporting)                                 41
# geo                                                             41
# Unit of measure                                                  2
# unit                                                             2
# Information society indicator                                    1
# indic_is                                                         1
# Statistical classification of economic activiti...              49
# TIME_PERIOD                                                     10
#
#                                                     % Cardinalidad
# Observation value                                             0.00
# Time                                                          0.00
# Confidentiality status (flag)                                 0.00
# CONF_STATUS                                                   0.00
# OBS_FLAG                                                      0.01
# Observation status (Flag) V2 structure                        0.01
# OBS_VALUE                                                    24.41
# Size classes in number of persons employed                    0.00
# size_emp                                                      0.00
# Time frequency                                                0.00
# freq                                                          0.00
# STRUCTURE_NAME                                                0.00
# STRUCTURE_ID                                                  0.00
# STRUCTURE                                                     0.00
# nace_r2                                                       0.22
# Geopolitical entity (reporting)                               0.18
# geo                                                           0.18
# Unit of measure                                               0.01
# unit                                                          0.01
# Information society indicator                                 0.00
# indic_is                                                      0.00
# Statistical classification of economic activiti...            0.21
# TIME_PERIOD                                                   0.04
# 🚩 FLAG: nulos - Clasificación por umbral (% nulos)
#   🟢 Bajo (≤ 5%):
#     - Ninguna
#   🟡 Moderado (5%–20%):
#     - OBS_VALUE (11.61%)
#   🔴 Alto (> 20%):
#     - Observation value (100.00%)
#     - Time (100.00%)
#     - Confidentiality status (flag) (99.19%)
#     - CONF_STATUS (99.19%)
#     - OBS_FLAG (88.74%)
#     - Observation status (Flag) V2 structure (88.74%)
#
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
#
# 📌 OBS_FLAG — 🚩 FLAG: nulos_categorica (88.74%)
#           Porcentaje  Recuento
# OBS_FLAG
# NaN            88.74     20571
# u              10.75      2492
# b               0.46       106
# bu              0.05        11
# 📌 Observation status (Flag) V2 structure — 🚩 FLAG: nulos_categorica (88.74%)
#                                         Porcentaje  Recuento
# Observation status (Flag) V2 structure
# NaN                                          88.74     20571
# low reliability                              10.75      2492
# break in time series                          0.46       106
# break in time series, low reliability         0.05        11
# 📌 CONF_STATUS — 🚩 FLAG: nulos_categorica (99.19%)
#              Porcentaje  Recuento
# CONF_STATUS
# NaN               99.19     22992
# C                  0.81       188
# 📌 Confidentiality status (flag) — 🚩 FLAG: nulos_categorica (99.19%)
#                                Porcentaje  Recuento
# Confidentiality status (flag)
# NaN                                 99.19     22992
# confidential                         0.81       188
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 Time — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📌 OBS_VALUE — 🚩 FLAG: nulos_numerica (11.61%)
# 📌 Observation value — 🚩 FLAG: nulos_numerica (100.00%)
# c:\Users\arant\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges
# C:\Users\arant\AppData\Local\Temp\ipykernel_20552\1775126049.py:165: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 📊 ESTADÍSTICAS DESCRIPTIVAS — NUMÉRICAS
#                      count         mean        std     min      25%     50%  \
# TIME_PERIOD        23180.0  2017.163762   3.301758  2012.0  2015.00  2017.0
# Time                   0.0          NaN        NaN     NaN      NaN     NaN
# OBS_VALUE          20489.0    29.750274  21.735693     0.0    15.39    22.5
# Observation value      0.0          NaN        NaN     NaN      NaN     NaN
#
#                        75%     max
# TIME_PERIOD        2019.00  2024.0
# Time                   NaN     NaN
# OBS_VALUE            34.67   100.0
# Observation value      NaN     NaN
# ✅ No se detectaron valores negativos en variables numéricas.
#
# ✅ No se detectaron variables con varianza 0.
#
# 🔤 ESTADÍSTICAS DESCRIPTIVAS — CATEGÓRICAS
#                                                     count unique  \
# STRUCTURE                                           23180      1
# STRUCTURE_ID                                        23180      1
# STRUCTURE_NAME                                      23180      1
# freq                                                23180      1
# Time frequency                                      23180      1
# size_emp                                            23180      1
# Size classes in number of persons employed          23180      1
# nace_r2                                             23180     51
# Statistical classification of economic activiti...  23180     49
# indic_is                                            23180      1
# Information society indicator                       23180      1
# unit                                                23180      2
# Unit of measure                                     23180      2
# geo                                                 23180     41
# Geopolitical entity (reporting)                     23180     41
# OBS_FLAG                                             2609      3
# Observation status (Flag) V2 structure               2609      3
# CONF_STATUS                                           188      1
# Confidentiality status (flag)                         188      1
#
#                                                                                                   top  \
# STRUCTURE                                                                                    dataflow
# STRUCTURE_ID                                                              ESTAT:ISOC_SKE_ITSPEN2(1.0)
# STRUCTURE_NAME                                      Enterprises that employ ICT specialists by NAC...
# freq                                                                                                A
# Time frequency                                                                                 Annual
# size_emp                                                                                         GE10
# Size classes in number of persons employed                                10 persons employed or more
# nace_r2                                                                                             C
# Statistical classification of economic activiti...                             Real estate activities
# indic_is                                                                                      E_ITSP2
# Information society indicator                       Enterprise employed ICT/IT specialists (reduce...
# unit                                                                                           PC_ENT
# Unit of measure                                                             Percentage of enterprises
# geo                                                                                                AT
# Geopolitical entity (reporting)                                                               Austria
# OBS_FLAG                                                                                            u
# Observation status (Flag) V2 structure                                                low reliability
# CONF_STATUS                                                                                         C
# Confidentiality status (flag)                                                            confidential
#
#                                                      freq
# STRUCTURE                                           23180
# STRUCTURE_ID                                        23180
# STRUCTURE_NAME                                      23180
# freq                                                23180
# Time frequency                                      23180
# size_emp                                            23180
# Size classes in number of persons employed          23180
# nace_r2                                               619
# Statistical classification of economic activiti...    689
# indic_is                                            23180
# Information society indicator                       23180
# unit                                                13975
# Unit of measure                                     13975
# geo                                                   640
# Geopolitical entity (reporting)                       640
# OBS_FLAG                                             2492
# Observation status (Flag) V2 structure               2492
# CONF_STATUS                                           188
# Confidentiality status (flag)                         188
# 📝 MUESTRA DE CATEGORÍAS (TOP 10) — VARIABLES CATEGÓRICAS
#
# 📌 STRUCTURE — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0        dataflow
# 📌 STRUCTURE_ID — 1 valores únicos (mostrando hasta 10)
#                Valor (muestra)
# 0  ESTAT:ISOC_SKE_ITSPEN2(1.0)
# 📌 STRUCTURE_NAME — 1 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  Enterprises that employ ICT specialists by NAC...
# 📌 freq — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               A
# 📌 Time frequency — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          Annual
# 📌 size_emp — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0            GE10
# 📌 Size classes in number of persons employed — 1 valores únicos (mostrando hasta 10)
#                Valor (muestra)
# 0  10 persons employed or more
# 📌 nace_r2 — 51 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               C
# 1             C-E
# 2             C-F
# 3         C10-C12
# 4         C10-C18
# 5    C10-S951_X_K
# 6         C13-C15
# 7         C16-C18
# 8             C19
# 9         C19-C23
# 📌 Statistical classification of economic activities in the European Community (NACE Rev. 2) — 49 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0                                      Manufacturing
# 1  Manufacturing, electricity, gas, steam and air...
# 2  Manufacturing, electricity, gas, steam and air...
# 3  Manufacture of food products; beverages and to...
# 4  Manufacture of products based on: food, bevera...
# 5  All activities (except agriculture, forestry a...
# 6  Manufacture of textiles, wearing apparel, leat...
# 7  Manufacture of wood, paper, printing and repro...
# 8  Manufacture of coke and refined petroleum prod...
# 9  Manufacture of coke, refined petroleum, chemic...
# 📌 indic_is — 1 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0         E_ITSP2
# 📌 Information society indicator — 1 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0  Enterprise employed ICT/IT specialists (reduce...
# 📌 unit — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0          PC_ENT
# 1     PC_ENT_CUSE
# 📌 Unit of measure — 2 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0                          Percentage of enterprises
# 1  Percentage of the enterprises which use a comp...
# 📌 geo — 41 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0              AL
# 1              AT
# 2              BA
# 3              BE
# 4              BG
# 5              CY
# 6              CZ
# 7              DE
# 8              DK
# 9              EA
# 📌 Geopolitical entity (reporting) — 41 valores únicos (mostrando hasta 10)
#                                      Valor (muestra)
# 0                                            Albania
# 1                                            Austria
# 2                             Bosnia and Herzegovina
# 3                                            Belgium
# 4                                           Bulgaria
# 5                                             Cyprus
# 6                                            Czechia
# 7                                            Germany
# 8                                            Denmark
# 9  Euro area (EA11-1999, EA12-2001, EA13-2007, EA...
# 📌 OBS_FLAG — 4 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               b
# 1               u
# 2              bu
# 📌 Observation status (Flag) V2 structure — 4 valores únicos (mostrando hasta 10)
#                          Valor (muestra)
# 0                   break in time series
# 1                        low reliability
# 2  break in time series, low reliability
# 📌 CONF_STATUS — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0               C
# 📌 Confidentiality status (flag) — 2 valores únicos (mostrando hasta 10)
#   Valor (muestra)
# 0    confidential
# ⚠️ OUTLIERS — Método IQR (1.5x)
# 🚩 FLAG: outliers - OBS_VALUE: 2429 (11.86%)
# 🏁 REVISIÓN EDA FINALIZADA
